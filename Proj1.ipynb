# %% [markdown]
# https://medium.com/@jordan.l.edmunds/please-stop-hard-coding-file-paths-609c769f9537 - no more hard-coding file paths!
#
# Importing the excel file:

# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

def directory_fxn():
    # Desktop directory
    desktop_directory = os.path.join(os.path.expanduser("~"), "Desktop")

    # Specify the folder and file name
    folder_name = "Oliynyk"
    file_name = "element_properties_for_ML.xlsx"

    # Construct the full path
    file_path = os.path.join(desktop_directory, folder_name, file_name)

    return file_path

# Call the function to get the file path
file_path = directory_fxn()

# Read the Excel file
df = pd.read_excel(file_path)

# Removing newline character, '\n'
df.columns = [col.replace('\n', ' ') for col in df.columns]

# Display entire df
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df
# Out:
#    Symbol  Atomic  weight  Atomic  number  Period  Group  Mendeleev number  \
# 0      Si        28.08550              14       3     14                78
# 1      Sc        44.95591              21       4      3                11
# 2      Fe        55.84700              26       4      8                55
# 3      Co        58.93320              27       4      9                58
# 4      Ni        58.69340              28       4     10                61
# 5      Ga        69.72300              31       4     13                74
# 6      Ge        72.63000              32       4     14                79
# 7       Y        88.90584              39       5      3                12
# 8      Ru       101.07000              44       5      8                56
# 9      Rh       102.90550              45       5      9                59
# 10     Pd       106.42000              46       5     10                62
# 11     In       114.81800              49       5     13                75
# 12     Sn       118.71000              50       5     14                80
# 13     Sb       121.76000              51       5     15                85
# 14     La       138.90550              57       6      3                13
# 15     Ce       140.11500              58       6      3                15
# 16     Pr       140.90765              59       6      3                17
# 17     Nd       144.24200              60       6      3                19
# 18     Sm       150.36000              62       6      3                23
# 19     Eu       151.96500              63       6      3                25
# 20     Gd       157.25000              64       6      3                27
# 21     Tb       158.92534              65       6      3                29
# 22     Dy       162.50000              66       6      3                31
# 23     Ho       164.93032              67       6      3                33
# 24     Er       167.25900              68       6      3                35
# 25     Tm       168.93421              69       6      3                37
# 26     Yb       173.04500              70       6      3                39
# 27     Lu       174.96700              71       6      3                41
# 28     Os       190.23000              76       6      8                57
# 29     Ir       192.21700              77       6      9                60
# 30     Pt       195.08400              78       6     10                63
# 31     Th       232.03810              90       7      3                16
# 32      U       238.02890              92       7      3                20
#
#     valence e total  unpaired electrons  Gilman no. of valence electrons  \
# 0                 4                   2                                4
# 1                 3                   1                                1
# 2                 8                   4                                5
# 3                 9                   3                                4
# 4                10                   2                                3
# 5                13                   1                                3
# 6                14                   2                                4
# 7                 3                   1                                1
# 8                 8                   3                                5
# 9                 9                   2                                4
# 10               10                   0                                3
# 11               13                   1                                3
# 12               14                   2                                4
# 13               15                   3                                5
# 14                3                   1                                1
# 15                4                   1                                3
# 16                5                   3                                3
# 17                6                   4                                3
# 18                8                   6                                3
# 19                9                   7                                3
# 20               10                   7                                3
# 21               11                   5                                3
# 22               12                   4                                3
# 23               13                   3                                3
# 24               14                   2                                3
# 25               15                   1                                3
# 26               16                   0                                3
# 27               17                   1                                1
# 28                8                   4                                5
# 29                9                   3                                4
# 30               10                   1                                3
# 31                4                   2                                2
# 32                6                   3                                3
#
#       Zeff  Ionization energy (eV)  CN  ratio n closest/CN  \
# 0   2.3210                  8.1517   4            1.000000
# 1   2.7770                  6.5615  12            0.500000
# 2   3.0478                  7.9024  14            0.571429
# 3   3.0460                  7.8810  12            0.500000
# 4   2.9960                  7.6398  12            1.000000
# 5   2.6550                  5.9993   7            0.142857
# 6   3.0460                  7.8994   4            1.000000
# 7   3.3790                  6.2173  12            0.500000
# 8   3.6760                  7.3605  12            0.500000
# 9   3.7010                  7.4589  12            1.000000
# 10  3.1010                  8.3369  12            1.000000
# 11  3.2590                  5.7864  12            0.333333
# 12  3.6720                  7.3439   6            0.666667
# 13  3.9840                  8.6084   6            0.500000
# 14  3.8400                  5.5769  12            0.500000
# 15  3.7740                  5.5387  12            0.500000
# 16  3.8000                  5.4730  12            0.500000
# 17  3.8220                  5.5250  12            0.500000
# 18  3.8470                  5.6437  12            0.500000
# 19  3.8710                  5.6704  14            0.571429
# 20  4.0340                  6.1498  12            0.500000
# 21  3.9760                  5.8638  12            0.500000
# 22  3.9630                  5.9389  12            0.500000
# 23  3.9940                  6.0215  12            0.500000
# 24  4.0180                  6.1077  12            0.500000
# 25  3.9210                  6.1843  12            0.500000
# 26  4.0480                  6.2542  12            1.000000
# 27  4.0340                  5.4259  12            0.500000
# 28  5.6480                  8.4382  12            0.500000
# 29  4.9080                  8.9670  12            1.000000
# 30  4.8830                  8.9588  12            1.000000
# 31  4.6790                  6.3067  12            1.000000
# 32  4.7210                  6.1941  12            0.166667
#
#     polyhedron distortion (dmin/dn)  CIF radius element  Pauling,  R(CN12)  \
# 0                             1.000               1.176              1.316
# 1                             0.984               1.641              1.620
# 2                             0.866               1.242              1.260
# 3                             0.996               1.250              1.252
# 4                             1.000               1.246              1.244
# 5                             0.897               1.243              1.408
# 6                             1.000               1.225              1.366
# 7                             0.975               1.783              1.797
# 8                             0.978               1.324              1.336
# 9                             1.000               1.345              1.342
# 10                            1.000               1.376              1.373
# 11                            0.962               1.624              1.660
# 12                            0.949               1.511              1.620
# 13                            0.868               1.434              1.590
# 14                            0.991               1.871              1.871
# 15                            0.990               1.819              1.818
# 16                            0.991               1.820              1.824
# 17                            0.992               1.813              1.818
# 18                            0.990               1.793              1.850
# 19                            0.866               1.987              2.084
# 20                            0.983               1.787              1.795
# 21                            0.978               1.764              1.773
# 22                            0.976               1.752              1.770
# 23                            0.975               1.745              1.761
# 24                            0.974               1.734              1.748
# 25                            0.974               1.726              1.743
# 26                            1.000               1.939              1.933
# 27                            0.979               1.718              1.738
# 28                            0.978               1.337              1.350
# 29                            1.000               1.356              1.355
# 30                            1.000               1.387              1.385
# 31                            1.000               1.798              1.795
# 32                            0.823               1.377              1.516
#
#     Pauling  EN  Martynov  Batsanov EN  Melting point, K  Density,  g/mL  \
# 0          1.90                   1.98           1683.15            2.33
# 1          1.36                   1.50           1814.15            2.99
# 2          1.83                   1.67           1808.15            7.86
# 3          1.88                   1.72           1768.15            8.90
# 4          1.91                   1.76           1726.15            8.90
# 5          1.81                   1.70            302.95            5.90
# 6          2.01                   1.99           1220.55            5.32
# 7          1.22                   1.41           1796.15            4.47
# 8          2.20                   1.97           2583.15           12.40
# 9          2.28                   1.99           2239.15           12.40
# 10         2.20                   2.08           1827.15           12.00
# 11         1.78                   1.63            429.75            7.31
# 12         1.96                   1.88            505.15            7.31
# 13         2.05                   2.14            904.15            6.69
# 14         1.10                   1.35           1193.15            6.15
# 15         1.12                   1.10           1071.15            6.66
# 16         1.13                   1.10           1204.15            6.77
# 17         1.14                   1.20           1289.15            7.00
# 18         1.17                   1.20           1347.15            7.52
# 19         1.20                   1.15           1095.15            5.24
# 20         1.20                   1.10           1586.15            7.90
# 21         1.20                   1.20           1638.15            8.23
# 22         1.22                   1.15           1685.15            8.55
# 23         1.23                   1.20           1747.15            8.80
# 24         1.24                   1.20           1802.15            9.07
# 25         1.25                   1.20           1818.15            9.32
# 26         1.10                   1.10           1092.15            6.97
# 27         1.27                   1.20           1936.15            9.84
# 28         2.20                   1.85           3318.15           22.60
# 29         2.20                   1.87           2683.15           22.40
# 30         2.28                   1.91           2045.15           21.40
# 31         1.30                   1.30           2023.15           11.70
# 32         1.38                   1.70           1405.15           19.00
#
#     Specific heat, J/g K  Cohesive  energy  Bulk modulus, GPa  \
# 0                  0.710              4.63               98.0
# 1                  0.600              3.90               56.6
# 2                  0.440              4.28              166.0
# 3                  0.420              4.39              182.0
# 4                  0.440              4.44              177.0
# 5                  0.370              2.81               56.9
# 6                  0.320              3.85               77.2
# 7                  0.300              4.37               41.2
# 8                  0.238              6.74              286.0
# 9                  0.242              5.75              276.0
# 10                 0.240              3.89              187.0
# 11                 0.230              2.52               41.1
# 12                 0.227              3.14               58.2
# 13                 0.210              2.75               38.3
# 14                 0.190              4.47               27.9
# 15                 0.190              4.32               21.5
# 16                 0.190              3.70               28.8
# 17                 0.190              3.40               31.8
# 18                 0.200              2.14               37.8
# 19                 0.180              1.86               14.7
# 20                 0.230              4.14               37.9
# 21                 0.180              4.05               38.7
# 22                 0.170              3.04               40.5
# 23                 0.160              3.14               40.2
# 24                 0.170              3.29               44.4
# 25                 0.160              2.42               44.5
# 26                 0.150              1.60               30.5
# 27                 0.150              4.43               47.6
# 28                 0.130              8.17              373.0
# 29                 0.130              6.94              371.0
# 30                 0.130              5.84              276.0
# 31                 0.120              6.20               54.0
# 32                 0.120              5.55               97.9
#
#     Abundance in Earth's  crust  Abundance  in solar system  (log)  \
# 0                  2.878989e-01                       3.261115e-05
# 1                  2.246020e-05                       1.115301e-09
# 2                  5.747769e-02                       2.935003e-05
# 3                  2.552295e-05                       7.337508e-08
# 4                  8.575712e-05                       1.607729e-06
# 5                  1.939744e-05                       1.232701e-09
# 6                  1.531377e-06                       3.880726e-09
# 7                  3.369030e-05                       1.513157e-10
# 8                  1.020918e-09                       6.065673e-11
# 9                  1.020918e-09                       1.121823e-11
# 10                 1.531377e-08                       4.532949e-11
# 11                 2.552295e-07                       6.000451e-12
# 12                 2.348112e-06                       1.245746e-10
# 13                 2.041836e-07                       1.007684e-11
# 14                 3.981581e-05                       1.454457e-11
# 15                 6.789105e-05                       3.704626e-11
# 16                 9.392446e-06                       5.442800e-12
# 17                 4.236810e-05                       2.699877e-11
# 18                 7.197472e-06                       8.420198e-12
# 19                 2.041836e-06                       3.173064e-12
# 20                 6.329692e-06                       1.076168e-11
# 21                 1.225102e-06                       1.966452e-12
# 22                 5.308774e-06                       1.285531e-11
# 23                 1.327194e-06                       2.899131e-12
# 24                 3.573213e-06                       8.178875e-12
# 25                 5.308774e-07                       1.232701e-12
# 26                 3.266938e-06                       8.084303e-12
# 27                 8.167345e-07                       1.196829e-12
# 28                 1.531377e-09                       2.201252e-11
# 29                 1.020918e-09                       2.155597e-11
# 30                 5.104590e-09                       4.369893e-11
# 31                 9.800814e-06                       1.092473e-12
# 32                 2.756479e-06                       2.935003e-13
#
#     HHI production  HHI reserve  cost,  pure ($/100g)
# 0           4708.0       1000.0                   5.4
# 1           5500.0       4500.0                1400.0
# 2           2424.0       1373.0                   6.7
# 3           3052.0       2655.0                  21.0
# 4            988.0       1479.0                   7.7
# 5           5500.0       1895.0                 220.0
# 6           5267.0       1895.0                 360.0
# 7           9834.0       2646.0                 220.0
# 8           3239.0       8000.0                1400.0
# 9           3239.0       8000.0               13000.0
# 10          3239.0       8000.0                  15.0
# 11          3333.0       2000.0                 120.0
# 12          2591.0       1639.0                   8.0
# 13          7906.0       3419.0                   4.5
# 14          9476.0       3129.0                  64.0
# 15          9476.0       3129.0                  57.0
# 16          9476.0       3129.0                 170.0
# 17          9476.0       3129.0                 110.0
# 18          9476.0       3129.0                 130.0
# 19          9476.0       3129.0                3600.0
# 20          9476.0       3129.0                 191.0
# 21          9476.0       3129.0                1800.0
# 22          9476.0       3129.0                 210.0
# 23          9476.0       3129.0                 740.0
# 24          9476.0       3129.0                 270.0
# 25          9476.0       3129.0                4100.0
# 26          9476.0       3129.0                 530.0
# 27          9476.0       3129.0                6900.0
# 28          5504.0       9087.0                7700.0
# 29          5504.0       9087.0                4200.0
# 30          5504.0       9087.0                4700.0
# 31             NaN          NaN                9000.0
# 32             NaN          NaN                6000.0

# %% [markdown]
# The shared python code will allow you to practice problem solving. Try to modify the provided code with chemical compositions to:
#
# 1. output a molar mass
# 2. read the data from a file
# 3. sort formulas based on EN.

# %% [markdown]
# Importing provided code:

# %%
import os

oliynyk_path = "/Users/emiljaffal/Desktop/Oliynyk"
# Change the current working directory
os.chdir(oliynyk_path)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import collections

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

#Creates an dataframe NewElem that contains the values from Oliynyk_Element_Properties_Dataset
NewElem = pd.read_excel('element_properties_for_ML.xlsx') #, engine='openpyxl')
NewElem = NewElem.replace({"^\s*|\s*$":""}, regex=True) #Remove whitespaces in rows
NewElem.columns = NewElem.columns.str.replace(' ','') #Remove whitespaces in columns
NewElem['Symbol'].str.len() # check for whitespaces
NewElem = NewElem.reset_index() #Reset the indexes 
NewElem.columns = NewElem.columns.str.replace('[\n]', '') 
NewElem.index = NewElem.index + 1
NewElem = NewElem.fillna(0)
NewElem

#Test formulas 

List_A = ["Sc", "Y", "La", "Ce", "Pr", "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Th", "U"]
List_B = ["Si", "Ga", "Ge", "In", "Sn", "Sb"]

composition = ["NdSi2", "Th2Os", "Sn5Co2", "Sm5Co7", "FeSb2", "Lu3Co2", 'SiC']

df = pd.DataFrame(composition, columns=["Entry formula"])

Element1 = []
Composition2 = []
strings = list(df['Entry formula'])
for s in strings:
    Composition2.append(list(map(lambda x:'1' if x=="" else x,re.findall(r"[A-Z][a-z]*\s*([-*\.\d]*)", s))))
    Element1.append(re.findall(r"[A-Z][a-z]*\s*", s))  
	
for i in range(0, len(Element1)):
    if Element1[i][0] not in List_A:
        Element1[i][0], Element1[i][1] = Element1[i][1], Element1[i][0]
        Composition2[i][0], Composition2[i][1] = Composition2[i][1], Composition2[i][0]
		
		
df1 = pd.DataFrame(Element1, columns=['Element A', 'Element B'])
df2 = pd.DataFrame(Composition2, columns=['Index_A', 'Index_B'])
df2 = df2.apply(pd.to_numeric, errors='coerce')
df2.reset_index(drop=True)


df2['Normalized_Index_A'] = df2['Index_A'] / df2['Index_A'].max()
df2['Normalized_Index_B'] = df2['Index_B'] / df2['Index_B'].max()

main_df = pd.concat([df, df1], axis=1)
main_df = main_df.reset_index(drop=True)
main_df = pd.concat([main_df, df2], axis=1)
main_df = main_df.reset_index(drop=True)
main_df

main_df['A_AbundanceinEarthsCrust'] = main_df['Element A'].map(NewElem.set_index('Symbol')["AbundanceinEarth'scrust"])
main_df['B_AbundanceinEarthsCrust'] = main_df['Element B'].map(NewElem.set_index('Symbol')["AbundanceinEarth'scrust"])
main_df['A_Abundanceinsolarsystem'] = main_df['Element A'].map(NewElem.set_index('Symbol')["Abundanceinsolarsystem(log)"])
main_df['B_Abundanceinsolarsystem'] = main_df['Element B'].map(NewElem.set_index('Symbol')["Abundanceinsolarsystem(log)"])
main_df['A_HHIproduction'] = main_df['Element A'].map(NewElem.set_index('Symbol')["HHIproduction"])
main_df['B_HHIproduction'] = main_df['Element B'].map(NewElem.set_index('Symbol')["HHIproduction"])
main_df['A_HHIreserve'] = main_df['Element A'].map(NewElem.set_index('Symbol')['HHIreserve'])
main_df['B_HHIreserve'] = main_df['Element B'].map(NewElem.set_index('Symbol')['HHIreserve'])
main_df['weighted normalized Abundance in Earth’s crust (per atom)'] = (main_df['Index_A'] * main_df['A_AbundanceinEarthsCrust']) + (main_df['Index_B'] * main_df['B_AbundanceinEarthsCrust'])  / (
                                                          main_df['Index_A'] + main_df['Index_B']) 
main_df['weighted normalized Abundance in solar system crust (per atom)'] = (main_df['Index_A'] * main_df['A_Abundanceinsolarsystem']) + (main_df['Index_B'] * main_df['B_Abundanceinsolarsystem'])  / (
                                                          main_df['Index_A'] + main_df['Index_B']) 
main_df['weighted normalized HHI production (per atom)'] = (main_df['Index_A'] * main_df['A_HHIproduction']) + (main_df['Index_B'] * main_df['B_HHIproduction'])  / (
                                                          main_df['Index_A'] + main_df['Index_B']) 
main_df['weighted normalized HHI reserve (per atom)'] = (main_df['Index_A'] * main_df['A_HHIreserve']) + (main_df['Index_B'] * main_df['B_HHIreserve'])  / (
                                                          main_df['Index_A'] + main_df['Index_B']) 

main_df['A_Atomicweight'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Atomicweight'])
main_df['B_Atomicweight'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Atomicweight'])
main_df['molar_mass'] = main_df['A_Atomicweight'] + main_df['B_Atomicweight']
main_df['A/B_AtomicWeight'] = main_df['A_Atomicweight'] / main_df['B_Atomicweight']

main_df['A_Atomicnumber'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Atomicnumber'])
main_df['B_Atomicnumber'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Atomicnumber'])
main_df['A/B_AtomicNumber'] = main_df['A_Atomicnumber'] / main_df['B_Atomicnumber']
main_df['A_PeriodNumber'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Period']).astype(int, errors='ignore')
main_df['B_PeriodNumber'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Period']).astype(int, errors='ignore')
main_df['A_group number'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Group']).astype(int, errors='ignore')
main_df['B_group number'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Group']).astype(int, errors='ignore')
main_df['A-B_group number'] = main_df['A_group number'] - main_df['B_group number']

main_df['A_Mendeleevnumber'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Mendeleevnumber']).astype(int, errors='ignore')
main_df['B_Mendeleevnumber'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Mendeleevnumber']).astype(int, errors='ignore')
main_df['A-B_Mendeleevnumber'] = main_df['A_Mendeleevnumber'] - main_df['B_Mendeleevnumber']

main_df['A_valence e total'] = main_df['Element A'].map(NewElem.set_index('Symbol')['valenceetotal']).astype(int, errors='ignore')
main_df['B_valence e total'] = main_df['Element B'].map(NewElem.set_index('Symbol')['valenceetotal']).astype(int, errors='ignore')
main_df['A-B valence e total'] = main_df['A_valence e total'] - main_df['B_valence e total']
main_df['A+B valence e total'] = main_df['A_valence e total'] + main_df['B_valence e total']
main_df['Weighted_A+B valence e total'] = main_df['A+B valence e total']*main_df['Index_A']*main_df['Index_B']
main_df['Weighted_Normalised_A+B valence e total'] = main_df['A+B valence e total'] / np.max(main_df['A+B valence e total'])


main_df['A_unpairedelectrons'] = main_df['Element A'].map(NewElem.set_index('Symbol')['unpairedelectrons']).astype(int, errors='ignore')
main_df['B_unpairedelectrons'] = main_df['Element B'].map(NewElem.set_index('Symbol')['unpairedelectrons']).astype(int, errors='ignore')
main_df['A-Bunpairedelectrons'] = main_df['A_unpairedelectrons'] - main_df['B_unpairedelectrons']
main_df['A+Bunpairedelectrons'] = main_df['A_unpairedelectrons'] + main_df['B_unpairedelectrons']
main_df['Weighted_A+Bunpairedelectrons'] = main_df['A+Bunpairedelectrons']*main_df['Index_A']*main_df['Index_B']
main_df['Weighted_Normalised_A+Bunpairedelectrons'] = main_df['A+Bunpairedelectrons'] / np.max(main_df['A+Bunpairedelectrons'])

main_df['A_Gilman number of e'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Gilmanno.ofvalenceelectrons']).astype(int, errors='ignore')
main_df['B_Gilman number of e'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Gilmanno.ofvalenceelectrons']).astype(int, errors='ignore')
main_df['A-B Gilman number of e'] = main_df['A_Gilman number of e'] - main_df['B_Gilman number of e']
main_df['A+B Gilman number of e'] = main_df['A_Gilman number of e'] + main_df['B_Gilman number of e']
main_df['Weighted_A+B Gilman number of e'] = main_df['A+B Gilman number of e']*main_df['Index_A']*main_df['Index_B']
main_df['Weighted_Normalised_A+B Gilman number of e'] = main_df['A+B Gilman number of e'] / np.max(main_df['A+B Gilman number of e'])

main_df['A_Zeff'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Zeff']) 
main_df['B_Zeff'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Zeff']) 
main_df['A-B_Zeff'] = main_df['A_Zeff'] - main_df['B_Zeff']
main_df['A+B_Zeff'] = main_df['A_Zeff'] + main_df['B_Zeff']
main_df['Largest_Zeff'] = main_df[['A_Zeff', 'B_Zeff']].max(axis=1)
main_df['Lowest_Zeff'] = main_df[['A_Zeff', 'B_Zeff']].min(axis=1)
main_df['Avg_Zeff'] = (main_df['A_Zeff'] + main_df['B_Zeff'])/2

main_df['A_ionization energy'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Ionizationenergy(eV)']) 
main_df['B_ionization energy'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Ionizationenergy(eV)']) 
main_df['A-B_ionization energy'] = main_df['A_ionization energy'] - main_df['B_ionization energy']
main_df['A+B_ionization energy'] = main_df['A_ionization energy'] + main_df['B_ionization energy']
main_df['Largest_ionization energy'] = main_df[['A_ionization energy', 'B_ionization energy']].max(axis=1)
main_df['Lowest_ionization energy'] = main_df[['A_ionization energy', 'B_ionization energy']].min(axis=1)
main_df['Avg_ionization energy'] = (main_df['A_ionization energy'] + main_df['B_ionization energy'])/2


main_df['A_Coord_Number'] = main_df['Element A'].map(NewElem.set_index('Symbol')['CN']).astype(int, errors='ignore')
main_df['B_Coord_Number'] = main_df['Element B'].map(NewElem.set_index('Symbol')['CN']).astype(int, errors='ignore')
main_df['A-BCoord_Number'] = main_df['A_Coord_Number'] - main_df['B_Coord_Number']

main_df['A_ratio n closest/CN'] = main_df['Element A'].map(NewElem.set_index('Symbol')['rationclosest/CN']) 
main_df['B_ratio n closest/CN'] = main_df['Element B'].map(NewElem.set_index('Symbol')['rationclosest/CN']) 
main_df['Largest_ratio n closest/CN'] = main_df[['A_ratio n closest/CN', 'B_ratio n closest/CN']].max(axis=1)
main_df['Lowest_ratio n closest/CN'] = main_df[['A_ratio n closest/CN', 'B_ratio n closest/CN']].min(axis=1)
main_df['Avg_ratio n closest/CN'] = (main_df['A_ratio n closest/CN'] + main_df['B_ratio n closest/CN'])/2


main_df['A_polyhedron_distortion'] = main_df['Element A'].map(NewElem.set_index('Symbol')['polyhedrondistortion(dmin/dn)']) 
main_df['B_polyhedron_distortion'] = main_df['Element B'].map(NewElem.set_index('Symbol')['polyhedrondistortion(dmin/dn)']) 
main_df['Largest_polyhedron_distortion'] = main_df[['A_polyhedron_distortion', 'B_polyhedron_distortion']].max(axis=1)
main_df['Lowest_polyhedron_distortion'] = main_df[['A_polyhedron_distortion', 'B_polyhedron_distortion']].min(axis=1)
main_df['Avg_polyhedron_distortion'] = (main_df['A_polyhedron_distortion'] + main_df['B_polyhedron_distortion'])/2

main_df['A_CIF radius'] = main_df['Element A'].map(NewElem.set_index('Symbol')['CIFradiuselement']) 
main_df['B_CIF radius'] = main_df['Element B'].map(NewElem.set_index('Symbol')['CIFradiuselement']) 
main_df['A/B_CIF radius'] = main_df['A_CIF radius'] / main_df['B_CIF radius']
main_df['A-B_CIF radius'] = main_df['A_CIF radius'] - main_df['B_CIF radius']
main_df['Avg_CIF radius'] = (main_df['A_CIF radius'] + main_df['B_CIF radius'])/2

main_df['A_Pauling,R(CN12)'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Pauling,R(CN12)'])
main_df['B_Pauling,R(CN12)'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Pauling,R(CN12)'])
main_df['A/BPauling,R(CN12)'] = main_df['A_Pauling,R(CN12)'] / main_df['B_Pauling,R(CN12)']
main_df['A-BPauling,R(CN12)'] = main_df['A_Pauling,R(CN12)'] - main_df['B_Pauling,R(CN12)']
main_df['Avg_Pauling,R(CN12)'] = (main_df['A_Pauling,R(CN12)'] + main_df['B_Pauling,R(CN12)'])/2

main_df['A_Pauling EN'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Pauling,R(CN12)'])
main_df['B_Pauling EN'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Pauling,R(CN12)'])
main_df['A/BPauling EN'] = main_df['A_Pauling EN'] / main_df['B_Pauling EN']
main_df['A-BPauling EN'] = main_df['A_Pauling EN'] - main_df['B_Pauling EN']
main_df['Largest_Pauling EN'] = main_df[['A_Pauling EN', 'B_Pauling EN']].max(axis=1)
main_df['Lowest_Pauling EN'] = main_df[['A_Pauling EN', 'B_Pauling EN']].min(axis=1)
main_df['Avg_Pauling EN'] = (main_df['A_Pauling EN'] + main_df['B_Pauling EN'])/2

main_df['A_Melting point'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Meltingpoint,K']) 
main_df['B_Melting point'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Meltingpoint,K']) 
main_df['A/B_Melting point'] = main_df['A_Melting point'] / main_df['B_Melting point']
main_df['A-B_Melting point'] = main_df['A_Melting point'] - main_df['B_Melting point']
main_df['Largest_Melting point'] = main_df[['A_Melting point', 'B_Melting point']].max(axis=1)
main_df['Lowest_Melting point'] = main_df[['A_Melting point', 'B_Melting point']].min(axis=1)
main_df['Avg_Melting point'] = (main_df['A_Melting point'] + main_df['B_Melting point'])/2

main_df['A_MartynovBatsanovEN'] = main_df['Element A'].map(NewElem.set_index('Symbol')['MartynovBatsanovEN'])
main_df['B_MartynovBatsanovEN'] = main_df['Element B'].map(NewElem.set_index('Symbol')['MartynovBatsanovEN'])
main_df['A-B_MartynovBatsanovEN'] = main_df['A_MartynovBatsanovEN'] - main_df['B_MartynovBatsanovEN']
main_df['A/B_MartynovBatsanovEN'] = main_df['A_MartynovBatsanovEN'] / main_df['B_MartynovBatsanovEN']
main_df['Largest_MartynovBatsanovEN'] = main_df[['A_MartynovBatsanovEN', 'B_MartynovBatsanovEN']].max(axis=1)
main_df['Lowest_MartynovBatsanovEN'] = main_df[['A_MartynovBatsanovEN', 'B_MartynovBatsanovEN']].min(axis=1)
main_df['Avg_MartynovBatsanovEN'] = (main_df['A_MartynovBatsanovEN'] + main_df['B_MartynovBatsanovEN'])/2
main_df['A_Density'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Density,g/mL'])
main_df['B_Density'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Density,g/mL'])
main_df['A-B_Density'] = main_df['A_Density'] - main_df['B_Density']
main_df['A/B_Density'] = main_df['A_Density'] / main_df['B_Density']
main_df['Largest_Density'] = main_df[['A_Density', 'B_Density']].max(axis=1)
main_df['Lowest_Density'] = main_df[['A_Density', 'B_Density']].min(axis=1)
main_df['Avg_Density'] = (main_df['A_Density'] + main_df['B_Density'])/2

main_df['A_Specific heat'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Specificheat,J/gK'])
main_df['B_Specific heat'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Specificheat,J/gK'])
main_df['A-B_Specific heat'] = main_df['A_Specific heat'] - main_df['A_Specific heat']
main_df['A/B_Specific heat'] = main_df['A_Specific heat'] / main_df['B_Specific heat']
main_df['Largest_Specific heat'] = main_df[['A_Specific heat', 'B_Specific heat']].max(axis=1)
main_df['Lowest_Specific heat'] = main_df[['A_Specific heat', 'B_Specific heat']].min(axis=1)
main_df['Avg_Specific heat'] = (main_df['A_Specific heat'] + main_df['B_Specific heat'])/2

main_df['A_Cohesiveenergy'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Cohesiveenergy'])
main_df['B_Cohesiveenergy'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Cohesiveenergy'])
main_df['A-B_Cohesiveenergy'] = main_df['A_Cohesiveenergy'] - main_df['B_Cohesiveenergy']
main_df['A/B_Cohesiveenergy'] = main_df['A_Cohesiveenergy'] / main_df['B_Cohesiveenergy']
main_df['Largest_Cohesiveenergy'] = main_df[['A_Cohesiveenergy', 'B_Cohesiveenergy']].max(axis=1)
main_df['Lowest_Cohesiveenergy'] = main_df[['A_Cohesiveenergy', 'B_Cohesiveenergy']].min(axis=1)
main_df['Avg_Cohesiveenergy'] = (main_df['A_Cohesiveenergy'] + main_df['B_Cohesiveenergy'])/2

main_df['A_Bulk modulus'] = main_df['Element A'].map(NewElem.set_index('Symbol')['Bulkmodulus,GPa'])
main_df['B_Bulk modulus'] = main_df['Element B'].map(NewElem.set_index('Symbol')['Bulkmodulus,GPa'])
main_df['A-B_Cohesiveenergy'] = main_df['A_Bulk modulus'] - main_df['B_Bulk modulus']
main_df['A/B_Cohesiveenergy'] = main_df['A_Bulk modulus'] / main_df['B_Bulk modulus']
main_df['Largest_Cohesiveenergy'] = main_df[['A_Bulk modulus', 'B_Bulk modulus']].max(axis=1)
main_df['Lowest_Cohesiveenergy'] = main_df[['A_Bulk modulus', 'B_Bulk modulus']].min(axis=1)
main_df['Avg_Cohesiveenergy'] = (main_df['A_Bulk modulus'] + main_df['B_Bulk modulus'])/2

main_df.to_excel('AntonDescriptorsForBinary.xlsx', index=False)
main_df
# Out:
#   Entry formula Element A Element B  Index_A  Index_B  Normalized_Index_A  \
# 0         NdSi2        Nd        Si        1        2                 0.2
# 1         Th2Os        Th        Os        2        1                 0.4
# 2        Sn5Co2        Co        Sn        2        5                 0.4
# 3        Sm5Co7        Sm        Co        5        7                 1.0
# 4         FeSb2        Sb        Fe        2        1                 0.4
# 5        Lu3Co2        Lu        Co        3        2                 0.6
# 6           SiC         C        Si        1        1                 0.2
#
#    Normalized_Index_B  A_AbundanceinEarthsCrust  B_AbundanceinEarthsCrust  \
# 0            0.285714              4.236810e-05              2.878989e-01
# 1            0.142857              9.800814e-06              1.531377e-09
# 2            0.714286              2.552295e-05              2.348112e-06
# 3            1.000000              7.197472e-06              2.552295e-05
# 4            0.142857              2.041836e-07              5.747769e-02
# 5            0.285714              8.167345e-07              2.552295e-05
# 6            0.142857                       NaN              2.878989e-01
#
#    A_Abundanceinsolarsystem  B_Abundanceinsolarsystem  A_HHIproduction  \
# 0              2.699877e-11              3.261115e-05           9476.0
# 1              1.092473e-12              2.201252e-11              0.0
# 2              7.337508e-08              1.245746e-10           3052.0
# 3              8.420198e-12              7.337508e-08           9476.0
# 4              1.007684e-11              2.935003e-05           7906.0
# 5              1.196829e-12              7.337508e-08           9476.0
# 6                       NaN              3.261115e-05              NaN
#
#    B_HHIproduction  A_HHIreserve  B_HHIreserve  \
# 0           4708.0        3129.0        1000.0
# 1           5504.0           0.0        9087.0
# 2           2591.0        2655.0        1639.0
# 3           3052.0        3129.0        2655.0
# 4           2424.0        3419.0        1373.0
# 5           3052.0        3129.0        2655.0
# 6           4708.0           NaN        1000.0
#
#    weighted normalized Abundance in Earth’s crust (per atom)  \
# 0                                           0.191975
# 1                                           0.000020
# 2                                           0.000053
# 3                                           0.000051
# 4                                           0.019160
# 5                                           0.000013
# 6                                                NaN
#
#    weighted normalized Abundance in solar system crust (per atom)  \
# 0                                       2.174079e-05
# 1                                       9.522454e-12
# 2                                       1.468391e-07
# 3                                       4.284423e-08
# 4                                       9.783364e-06
# 5                                       2.935362e-08
# 6                                                NaN
#
#    weighted normalized HHI production (per atom)  \
# 0                                   12614.666667
# 1                                    1834.666667
# 2                                    7954.714286
# 3                                   49160.333333
# 4                                   16620.000000
# 5                                   29648.800000
# 6                                            NaN
#
#    weighted normalized HHI reserve (per atom)  A_Atomicweight  B_Atomicweight  \
# 0                                 3795.666667        144.2420         28.0855
# 1                                 3029.000000        232.0381        190.2300
# 2                                 6480.714286         58.9332        118.7100
# 3                                17193.750000        150.3600         58.9332
# 4                                 7295.666667        121.7600         55.8470
# 5                                10449.000000        174.9670         58.9332
# 6                                         NaN             NaN         28.0855
#
#    molar_mass  A/B_AtomicWeight  A_Atomicnumber  B_Atomicnumber  \
# 0    172.3275          5.135817            60.0              14
# 1    422.2681          1.219777            90.0              76
# 2    177.6432          0.496447            27.0              50
# 3    209.2932          2.551363            62.0              27
# 4    177.6070          2.180242            51.0              26
# 5    233.9002          2.968904            71.0              27
# 6         NaN               NaN             NaN              14
#
#    A/B_AtomicNumber  A_PeriodNumber  B_PeriodNumber  A_group number  \
# 0          4.285714             6.0               3             3.0
# 1          1.184211             7.0               6             3.0
# 2          0.540000             4.0               5             9.0
# 3          2.296296             6.0               4             3.0
# 4          1.961538             5.0               4            15.0
# 5          2.629630             6.0               4             3.0
# 6               NaN             NaN               3             NaN
#
#    B_group number  A-B_group number  A_Mendeleevnumber  B_Mendeleevnumber  \
# 0              14             -11.0               19.0                 78
# 1               8              -5.0               16.0                 57
# 2              14              -5.0               58.0                 80
# 3               9              -6.0               23.0                 58
# 4               8               7.0               85.0                 55
# 5               9              -6.0               41.0                 58
# 6              14               NaN                NaN                 78
#
#    A-B_Mendeleevnumber  A_valence e total  B_valence e total  \
# 0                -59.0                6.0                  4
# 1                -41.0                4.0                  8
# 2                -22.0                9.0                 14
# 3                -35.0                8.0                  9
# 4                 30.0               15.0                  8
# 5                -17.0               17.0                  9
# 6                  NaN                NaN                  4
#
#    A-B valence e total  A+B valence e total  Weighted_A+B valence e total  \
# 0                  2.0                 10.0                          20.0
# 1                 -4.0                 12.0                          24.0
# 2                 -5.0                 23.0                         230.0
# 3                 -1.0                 17.0                         595.0
# 4                  7.0                 23.0                          46.0
# 5                  8.0                 26.0                         156.0
# 6                  NaN                  NaN                           NaN
#
#    Weighted_Normalised_A+B valence e total  A_unpairedelectrons  \
# 0                                 0.384615                  4.0
# 1                                 0.461538                  2.0
# 2                                 0.884615                  3.0
# 3                                 0.653846                  6.0
# 4                                 0.884615                  3.0
# 5                                 1.000000                  1.0
# 6                                      NaN                  NaN
#
#    B_unpairedelectrons  A-Bunpairedelectrons  A+Bunpairedelectrons  \
# 0                    2                   2.0                   6.0
# 1                    4                  -2.0                   6.0
# 2                    2                   1.0                   5.0
# 3                    3                   3.0                   9.0
# 4                    4                  -1.0                   7.0
# 5                    3                  -2.0                   4.0
# 6                    2                   NaN                   NaN
#
#    Weighted_A+Bunpairedelectrons  Weighted_Normalised_A+Bunpairedelectrons  \
# 0                           12.0                                  0.666667
# 1                           12.0                                  0.666667
# 2                           50.0                                  0.555556
# 3                          315.0                                  1.000000
# 4                           14.0                                  0.777778
# 5                           24.0                                  0.444444
# 6                            NaN                                       NaN
#
#    A_Gilman number of e  B_Gilman number of e  A-B Gilman number of e  \
# 0                   3.0                     4                    -1.0
# 1                   2.0                     5                    -3.0
# 2                   4.0                     4                     0.0
# 3                   3.0                     4                    -1.0
# 4                   5.0                     5                     0.0
# 5                   1.0                     4                    -3.0
# 6                   NaN                     4                     NaN
#
#    A+B Gilman number of e  Weighted_A+B Gilman number of e  \
# 0                     7.0                             14.0
# 1                     7.0                             14.0
# 2                     8.0                             80.0
# 3                     7.0                            245.0
# 4                    10.0                             20.0
# 5                     5.0                             30.0
# 6                     NaN                              NaN
#
#    Weighted_Normalised_A+B Gilman number of e  A_Zeff  B_Zeff  A-B_Zeff  \
# 0                                         0.7   3.822  2.3210    1.5010
# 1                                         0.7   4.679  5.6480   -0.9690
# 2                                         0.8   3.046  3.6720   -0.6260
# 3                                         0.7   3.847  3.0460    0.8010
# 4                                         1.0   3.984  3.0478    0.9362
# 5                                         0.5   4.034  3.0460    0.9880
# 6                                         NaN     NaN  2.3210       NaN
#
#    A+B_Zeff  Largest_Zeff  Lowest_Zeff  Avg_Zeff  A_ionization energy  \
# 0    6.1430         3.822       2.3210    3.0715               5.5250
# 1   10.3270         5.648       4.6790    5.1635               6.3067
# 2    6.7180         3.672       3.0460    3.3590               7.8810
# 3    6.8930         3.847       3.0460    3.4465               5.6437
# 4    7.0318         3.984       3.0478    3.5159               8.6084
# 5    7.0800         4.034       3.0460    3.5400               5.4259
# 6       NaN         2.321       2.3210       NaN                  NaN
#
#    B_ionization energy  A-B_ionization energy  A+B_ionization energy  \
# 0               8.1517                -2.6267                13.6767
# 1               8.4382                -2.1315                14.7449
# 2               7.3439                 0.5371                15.2249
# 3               7.8810                -2.2373                13.5247
# 4               7.9024                 0.7060                16.5108
# 5               7.8810                -2.4551                13.3069
# 6               8.1517                    NaN                    NaN
#
#    Largest_ionization energy  Lowest_ionization energy  Avg_ionization energy  \
# 0                     8.1517                    5.5250                6.83835
# 1                     8.4382                    6.3067                7.37245
# 2                     7.8810                    7.3439                7.61245
# 3                     7.8810                    5.6437                6.76235
# 4                     8.6084                    7.9024                8.25540
# 5                     7.8810                    5.4259                6.65345
# 6                     8.1517                    8.1517                    NaN
#
#    A_Coord_Number  B_Coord_Number  A-BCoord_Number  A_ratio n closest/CN  \
# 0            12.0               4              8.0                   0.5
# 1            12.0              12              0.0                   1.0
# 2            12.0               6              6.0                   0.5
# 3            12.0              12              0.0                   0.5
# 4             6.0              14             -8.0                   0.5
# 5            12.0              12              0.0                   0.5
# 6             NaN               4              NaN                   NaN
#
#    B_ratio n closest/CN  Largest_ratio n closest/CN  \
# 0              1.000000                    1.000000
# 1              0.500000                    1.000000
# 2              0.666667                    0.666667
# 3              0.500000                    0.500000
# 4              0.571429                    0.571429
# 5              0.500000                    0.500000
# 6              1.000000                    1.000000
#
#    Lowest_ratio n closest/CN  Avg_ratio n closest/CN  A_polyhedron_distortion  \
# 0                        0.5                0.750000                    0.992
# 1                        0.5                0.750000                    1.000
# 2                        0.5                0.583333                    0.996
# 3                        0.5                0.500000                    0.990
# 4                        0.5                0.535714                    0.868
# 5                        0.5                0.500000                    0.979
# 6                        1.0                     NaN                      NaN
#
#    B_polyhedron_distortion  Largest_polyhedron_distortion  \
# 0                    1.000                          1.000
# 1                    0.978                          1.000
# 2                    0.949                          0.996
# 3                    0.996                          0.996
# 4                    0.866                          0.868
# 5                    0.996                          0.996
# 6                    1.000                          1.000
#
#    Lowest_polyhedron_distortion  Avg_polyhedron_distortion  A_CIF radius  \
# 0                         0.992                     0.9960         1.813
# 1                         0.978                     0.9890         1.798
# 2                         0.949                     0.9725         1.250
# 3                         0.990                     0.9930         1.793
# 4                         0.866                     0.8670         1.434
# 5                         0.979                     0.9875         1.718
# 6                         1.000                        NaN           NaN
#
#    B_CIF radius  A/B_CIF radius  A-B_CIF radius  Avg_CIF radius  \
# 0         1.176        1.541667           0.637          1.4945
# 1         1.337        1.344802           0.461          1.5675
# 2         1.511        0.827267          -0.261          1.3805
# 3         1.250        1.434400           0.543          1.5215
# 4         1.242        1.154589           0.192          1.3380
# 5         1.250        1.374400           0.468          1.4840
# 6         1.176             NaN             NaN             NaN
#
#    A_Pauling,R(CN12)  B_Pauling,R(CN12)  A/BPauling,R(CN12)  \
# 0              1.818              1.316            1.381459
# 1              1.795              1.350            1.329630
# 2              1.252              1.620            0.772840
# 3              1.850              1.252            1.477636
# 4              1.590              1.260            1.261905
# 5              1.738              1.252            1.388179
# 6                NaN              1.316                 NaN
#
#    A-BPauling,R(CN12)  Avg_Pauling,R(CN12)  A_Pauling EN  B_Pauling EN  \
# 0               0.502               1.5670         1.818         1.316
# 1               0.445               1.5725         1.795         1.350
# 2              -0.368               1.4360         1.252         1.620
# 3               0.598               1.5510         1.850         1.252
# 4               0.330               1.4250         1.590         1.260
# 5               0.486               1.4950         1.738         1.252
# 6                 NaN                  NaN           NaN         1.316
#
#    A/BPauling EN  A-BPauling EN  Largest_Pauling EN  Lowest_Pauling EN  \
# 0       1.381459          0.502               1.818              1.316
# 1       1.329630          0.445               1.795              1.350
# 2       0.772840         -0.368               1.620              1.252
# 3       1.477636          0.598               1.850              1.252
# 4       1.261905          0.330               1.590              1.260
# 5       1.388179          0.486               1.738              1.252
# 6            NaN            NaN               1.316              1.316
#
#    Avg_Pauling EN  A_Melting point  B_Melting point  A/B_Melting point  \
# 0          1.5670          1289.15          1683.15           0.765915
# 1          1.5725          2023.15          3318.15           0.609722
# 2          1.4360          1768.15           505.15           3.500247
# 3          1.5510          1347.15          1768.15           0.761898
# 4          1.4250           904.15          1808.15           0.500041
# 5          1.4950          1936.15          1768.15           1.095015
# 6             NaN              NaN          1683.15                NaN
#
#    A-B_Melting point  Largest_Melting point  Lowest_Melting point  \
# 0             -394.0                1683.15               1289.15
# 1            -1295.0                3318.15               2023.15
# 2             1263.0                1768.15                505.15
# 3             -421.0                1768.15               1347.15
# 4             -904.0                1808.15                904.15
# 5              168.0                1936.15               1768.15
# 6                NaN                1683.15               1683.15
#
#    Avg_Melting point  A_MartynovBatsanovEN  B_MartynovBatsanovEN  \
# 0            1486.15                  1.20                  1.98
# 1            2670.65                  1.30                  1.85
# 2            1136.65                  1.72                  1.88
# 3            1557.65                  1.20                  1.72
# 4            1356.15                  2.14                  1.67
# 5            1852.15                  1.20                  1.72
# 6                NaN                   NaN                  1.98
#
#    A-B_MartynovBatsanovEN  A/B_MartynovBatsanovEN  Largest_MartynovBatsanovEN  \
# 0                   -0.78                0.606061                        1.98
# 1                   -0.55                0.702703                        1.85
# 2                   -0.16                0.914894                        1.88
# 3                   -0.52                0.697674                        1.72
# 4                    0.47                1.281437                        2.14
# 5                   -0.52                0.697674                        1.72
# 6                     NaN                     NaN                        1.98
#
#    Lowest_MartynovBatsanovEN  Avg_MartynovBatsanovEN  A_Density  B_Density  \
# 0                       1.20                   1.590       7.00       2.33
# 1                       1.30                   1.575      11.70      22.60
# 2                       1.72                   1.800       8.90       7.31
# 3                       1.20                   1.460       7.52       8.90
# 4                       1.67                   1.905       6.69       7.86
# 5                       1.20                   1.460       9.84       8.90
# 6                       1.98                     NaN        NaN       2.33
#
#    A-B_Density  A/B_Density  Largest_Density  Lowest_Density  Avg_Density  \
# 0         4.67     3.004292             7.00            2.33        4.665
# 1       -10.90     0.517699            22.60           11.70       17.150
# 2         1.59     1.217510             8.90            7.31        8.105
# 3        -1.38     0.844944             8.90            7.52        8.210
# 4        -1.17     0.851145             7.86            6.69        7.275
# 5         0.94     1.105618             9.84            8.90        9.370
# 6          NaN          NaN             2.33            2.33          NaN
#
#    A_Specific heat  B_Specific heat  A-B_Specific heat  A/B_Specific heat  \
# 0             0.19            0.710                0.0           0.267606
# 1             0.12            0.130                0.0           0.923077
# 2             0.42            0.227                0.0           1.850220
# 3             0.20            0.420                0.0           0.476190
# 4             0.21            0.440                0.0           0.477273
# 5             0.15            0.420                0.0           0.357143
# 6              NaN            0.710                NaN                NaN
#
#    Largest_Specific heat  Lowest_Specific heat  Avg_Specific heat  \
# 0                   0.71                 0.190             0.4500
# 1                   0.13                 0.120             0.1250
# 2                   0.42                 0.227             0.3235
# 3                   0.42                 0.200             0.3100
# 4                   0.44                 0.210             0.3250
# 5                   0.42                 0.150             0.2850
# 6                   0.71                 0.710                NaN
#
#    A_Cohesiveenergy  B_Cohesiveenergy  A-B_Cohesiveenergy  A/B_Cohesiveenergy  \
# 0              3.40              4.63               -66.2            0.324490
# 1              6.20              8.17              -319.0            0.144772
# 2              4.39              3.14               123.8            3.127148
# 3              2.14              4.39              -144.2            0.207692
# 4              2.75              4.28              -127.7            0.230723
# 5              4.43              4.39              -134.4            0.261538
# 6               NaN              4.63                 NaN                 NaN
#
#    Largest_Cohesiveenergy  Lowest_Cohesiveenergy  Avg_Cohesiveenergy  \
# 0                    98.0                   31.8               64.90
# 1                   373.0                   54.0              213.50
# 2                   182.0                   58.2              120.10
# 3                   182.0                   37.8              109.90
# 4                   166.0                   38.3              102.15
# 5                   182.0                   47.6              114.80
# 6                    98.0                   98.0                 NaN
#
#    A_Bulk modulus  B_Bulk modulus
# 0            31.8            98.0
# 1            54.0           373.0
# 2           182.0            58.2
# 3            37.8           182.0
# 4            38.3           166.0
# 5            47.6           182.0
# 6             NaN            98.0
