# %%
cd
# Out:
# /Users/emiljaffal

# %%
import pandas as pd

file_path = "desktop/data.xlsx"
data = pd.read_excel(file_path)
data
# Out:
#      Formula    Entry  Entry prototype  Structure class  Inv. center  \
# 0       CeGa   261037                1                1            1
# 1       CeGa   526690                1                1            1
# 2       CeGa   450659                1                1            1
# 3       CeGa   450525                1                1            1
# 4       CeGa   528215                1                1            1
# ...      ...      ...              ...              ...          ...
# 1447    NiPt  1627941               10                4            1
# 1448    NiPt   455847               10                4            1
# 1449    SnYb   450594               10                4            1
# 1450    SnYb  1823352               10                4            1
# 1451    SnYb  1907574               10                4            1
#
#       Unit cell volume, A^3  Density (calc.) [Mg m‰…]
# 0                   210.590                      6.62
# 1                   212.790                      6.55
# 2                   212.790                      6.55
# 3                   215.020                      6.48
# 4                   215.030                      6.48
# ...                     ...                       ...
# 1447                 26.500                     15.91
# 1448                 26.473                     15.92
# 1449                 54.147                      8.95
# 1450                 54.800                      8.84
# 1451                 54.000                      8.96
#
# [1452 rows x 7 columns]

# %% [markdown]
# ## How to train chemical formula only datasets
#
# For each chemical formula, we can obtain 438 descriptors consisting of features such as average electronegativity, average boiling points of elements etc. An example of getting descriptors is shown below:

# %%
import numpy as np
from jarvis.core.composition import Composition
from jarvis.core.specie import Specie
from jarvis.ai.pkgs.lgbm.regression import regression
from jarvis.ai.descriptors.cfid import get_chem_only_descriptors

formula_unitcell = data[['Formula', 'Unit cell volume, A^3']]

# Convert to NumPy array
X = []
Y = []
IDs = []
for ii, i in enumerate(formula_unitcell):
    X.append(get_chem_only_descriptors(i[0]))
    Y.append(i[1])
    IDs.append(ii)

X = np.array(X)
Y = np.array(Y).reshape(-1, 1)
IDs = np.array(IDs)

# %%
X
# Out:
# array([[['42.515', '85.03255', '11.48', '-7.798403199999999', '1.0',
#          '1.5756031999999998', '2.0', '212.78211583999996',
#          '126.35379061371842', '-50.03', '0.2785', '13.054400000000001',
#          '5.093', '0.0', '3.4723', '1932.490974729242', '7.26', '96.23',
#          '0.0', '7.2', '13.4', '4.5', '0.0', '1.5', '0.0', '2.9', '4.5',
#          '15.1', '50.25', '3.28255', '-14.142799999999998', '-11.1723',
#          '-7.219999999999999', '17.42025', '20.9228',
#          '0.9170665458873933', '-0.05700000000000005', '2.047',
#          '3.2463', '1.618', '62.314762496', '22.2784032',
#          '-3.2523000000000004', '0.02631800129391927',
#          '0.14285714285714285', '-1.0', '9.7044996',
#          '15.294285714285715', '4392.156862745098',
#          '2.8176052185269973', '-53.5023', '5.0', '10.7',
#          '196.078431372549', '53.53', '0.50255', '22.4984032',
#          '37.9968064', '0.0051', '2.21686', '17.4228', '89.01',
#          '-0.4723', '13.922799999999999', '16.8658', '-3.97745',
#          '195.13535999999996', '932.642484', '1615.434224096', '31.5',
#          '1.057', '0.02515', '64.73', '14.142799999999998',
#          '19.026103199999998', '685.8629314079423',
#          '1.5556071428571427', '0.010405380160657576',
#          '3.2523000000000004', '0.0', '2.2989', '-34.5315968',
#          '7.699999999999999', '0.203382525', '10.5821105824', '70.9528',
#          '36.421203199999994', '952.3359999999999',
#          '30.198403199999998', '0.0', '-3.49745', '0.3125',
#          '0.04442814', '1016.9845232959999', '0.557', '-17.3951',
#          '7.919999999999999', '0.0554', '-1.5756031999999998', '1.99',
#          '42.33', '2.998941550041162e-05', '11.1723',
#          '-6.222799999999999', '1.97', '0.110246', '7.219999999999999',
#          '-0.6999999999999997', '0.5', '81.75', '0.031969603048878484',
#          '26.765', '29.81621', '0.20490179936493', '18.9984032',
#          '85.0023', '104.0284032', '218.4313725490196', '0.001275',
#          '4.977942857142857', '53.557700000000004', '0.04844592816',
#          '0.00022767857142857146', '0.004578096947935368',
#          '6832.470588235293', '-15.718403199999997', '0.008925',
#          '-3.423', '0.090856', '-18.4984032', '0.0',
#          '-15.498403199999998', '44.576', '-53.52745', '22.4',
#          '18.4414032', '0.044642857142857144', '88.31', '7.2', '2.9',
#          '0.0', '-1.9', '0.0', '0.3', '0.0', '22.3',
#          '0.0007285714285714286', '-18.4414032', '0.0', '0.0', '3.48',
#          '0.6999999999999997', '3.5', '72.5284032', '56.81', '0.0',
#          '85.587', '0.5595500000000001', '-13.442799999999998',
#          '36.107200000000006', '1.75', '-42.33', '0.35491132449093965',
#          '2.943', '4.880386619831485', '54.087', '0.5847', '-0.49745',
#          '628.9819494584838', '-15.018403199999998', '-73.83',
#          '0.0154289', '81.53', '2.047', '3.2463', '1.618', '-3.48',
#          '7.48', '187.35500000000002', '34.5315968', '57.03',
#          '10.862745098039214', '4.475639300043912', '69.342744',
#          '0.02856', '0.04116194284370222', '3.1999999999999997',
#          '5.4281152', '0.0', '20.10771992818671', '18.9707032',
#          '18.050541516245488', '34.10844380610413', '85.53', '3.49745',
#          '-84.473', '0.0065506291896977546', '175.57840000000002',
#          '0.0', '1.696286', '4.779464285714286', '-3.4723',
#          '18.4984032', '0.15914285714285717', '-52.973',
#          '0.5293000000000001', '8.889', '-1.0', '1.6400000000000001',
#          '-0.5293000000000001', '-81.53', '88.53', '0.0', '213.0494',
#          '9.4992016', '60.9798', '-0.21999999999999975',
#          '1.5884550719222865', '-10.7', '85.02745', '-16.9228',
#          '4.763683915561368e-05', '-36.107200000000006', '54.03',
#          '19.000953199999998', '73.83', '17.425349999999998', '84.53',
#          '170.06', '0.3', '18.9958532', '53.5023', '1.114', '11.757',
#          '102.4528', '-0.02515', '20992.156862745098', '-81.05',
#          '4551.6559', '0.5262557686399999', '404.3321299638989',
#          '-0.48', '6.222799999999999', '3.837', '-18.9707032',
#          '-85.02745', '7.798403199999999', '3.98', '0.0', '-17.42025',
#          '0.32547730244722584', '0.5277', '0.8976660682226211',
#          '0.0001342218065989883', '1.482781', '21.4028', '4.057',
#          '10.642999999999999', '0.0015898707440824666', '297.605',
#          '19.4984032', '0.13650150000000003', '6.283662477558348',
#          '3.3077', '6.1', '0.0', '3.50255', '0.0', '1.5', '-1.9', '0.0',
#          '1.5', '0.0', '4.6', '0.04973070017953321', '599.536',
#          '49.550000000000004', '66.0315968', '17.450499999999998',
#          '0.18422600905743491', '15.498403199999998', '0.03025',
#          '0.009340556697179151', '50.03', '0.0014203500000000001',
#          '33345.098039215685', '0.007914285714285714', '16.9228',
#          '-84.53', '4.48', '14.7', '0.705', '7.591964285714286',
#          '-53.03', '66.4944112', '4.0077', '0.4723',
#          '17.979799999999997', '47.36171', '57.146784',
#          '-7.919999999999999', '2.0', '11.19745', '0.22343176761143124',
#          '84.473', '138.56', '0.049732142857142864',
#          '0.21999999999999975', '3.7800000000000002', '11.7',
#          '0.010149', '53.52745', '0.2008861951006727',
#          '0.02869802787152467', '36.736', '0.0', '7.0635e-05',
#          '0.09205776173285199', '0.0024732142857142856',
#          '3.2800000000000002', '107.06', '2.7230000000000003',
#          '0.029318253441426072', '-2.7800000000000002',
#          '3069.675090252708', '75.613644736', '96.10412926391382',
#          '2.7800000000000002', '7.0', '-11.19745', '11.227699999999999',
#          '338.4194', '0.000517466841023725', '52.973',
#          '0.005880277549100317', '0.49745', '-2.7230000000000003',
#          '0.0014580172716831276', '24.294285714285714', '85.0577',
#          '0.00014635994214477584', '13.93', '81.05', '-2.943', '17.0',
#          '31.279712746858163', '331.00537927295994',
#          '0.31023999999999996', '2.355331', '11.2',
#          '39.199999999999996', '15.718403199999997',
#          '1.090433409096127', '-3.2774500000000004', '1481.460684',
#          '6.2384', '19.555403199999997', '278.89840000000004', '3.0',
#          '57.51', '-81.75', '20.108303249097474', '1.9495000000000002',
#          '85.03', '0.09695', '-50.25', '0.0', '0.0', '1.5', '0.0',
#          '2.7', '0.0', '13.442799999999998', '0.0', '-31.5',
#          '11.202549999999999', '2.0', '-3.0', '3.9523', '-16.8658',
#          '-18.9958532', '0.1317182170998471', '17.3951', '6.78',
#          '1372.549019607843', '0.0277', '67.6072', '0.48',
#          '0.0003257673762201576', '0.62954251440668', '34.8456',
#          '-0.55445', '0.209228470016813', '4.0', '5.6', '8.7114',
#          '0.2168265', '-13.922799999999999', '9.0', '0.55445', '4.537',
#          '0.0', '1.0', '-67.6072', '0.06538389688025406',
#          '7450.3541960784305', '-1.6980609575', '3.2774500000000004',
#          '-66.0315968', '20.7028', '28.622799999999998',
#          '0.008364000000000002', '1.8269600000000004', '3.98255',
#          '53.53255', '-85.0023', '152.65709156193896', '3.97745',
#          '0.01385', '3.5277', '2.2989', '3.423', '0.6428358243221526',
#          '3.0724108639254313', '-7.699999999999999', '14.48', '15.18',
#          '22.9784032', '0.05700000000000005', '0.5895232289837916',
#          '-10.642999999999999', '53.03', '-49.550000000000004',
#          '15.018403199999998', '17.9228', '-3.9523', '0.00255',
#          '0.48261155999999994', '42.515', '85.03255', '11.48',
#          '-7.798403199999999', '1.0', '1.5756031999999998', '2.0',
#          '212.78211583999996', '126.35379061371842', '-50.03', '0.2785',
#          '13.054400000000001', '5.093', '0.0', '3.4723',
#          '1932.490974729242', '7.26', '96.23', '0.0', '7.2', '13.4',
#          '4.5', '0.0', '1.5', '0.0', '2.9', '4.5', '15.1', '50.25',
#          '3.28255', '-14.142799999999998', '-11.1723',
#          '-7.219999999999999', '17.42025', '20.9228',
#          '0.9170665458873933', '-0.05700000000000005', '2.047',
#          '3.2463', '1.618', '62.314762496', '22.2784032',
#          '-3.2523000000000004', '0.02631800129391927',
#          '0.14285714285714285', '-1.0', '9.7044996',
#          '15.294285714285715', '4392.156862745098',
#          '2.8176052185269973', '-53.5023', '5.0', '10.7',
#          '196.078431372549', '53.53', '0.50255', '22.4984032',
#          '37.9968064', '0.0051', '2.21686', '17.4228', '89.01',
#          '-0.4723', '13.922799999999999', '16.8658', '-3.97745',
#          '195.13535999999996', '932.642484', '1615.434224096', '31.5',
#          '1.057', '0.02515', '64.73', '14.142799999999998',
#          '19.026103199999998', '685.8629314079423',
#          '1.5556071428571427', '0.010405380160657576',
#          '3.2523000000000004', '0.0', '2.2989', '-34.5315968',
#          '7.699999999999999', '0.203382525', '10.5821105824', '70.9528',
#          '36.421203199999994', '952.3359999999999',
#          '30.198403199999998', '0.0', '-3.49745', '0.3125',
#          '0.04442814', '1016.9845232959999', '0.557', '-17.3951',
#          '7.919999999999999', '0.0554', '-1.5756031999999998', '1.99',
#          '42.33', '2.998941550041162e-05', '11.1723',
#          '-6.222799999999999', '1.97', '0.110246', '7.219999999999999',
#          '-0.6999999999999997', '0.5', '81.75', '0.031969603048878484',
#          '26.765', '29.81621', '0.20490179936493', '18.9984032',
#          '85.0023', '104.0284032', '218.4313725490196', '0.001275',
#          '4.977942857142857', '53.557700000000004', '0.04844592816',
#          '0.00022767857142857146', '0.004578096947935368',
#          '6832.470588235293', '-15.718403199999997', '0.008925',
#          '-3.423', '0.090856', '-18.4984032', '0.0',
#          '-15.498403199999998', '44.576', '-53.52745', '22.4',
#          '18.4414032', '0.044642857142857144', '88.31', '7.2', '2.9',
#          '0.0', '-1.9', '0.0', '0.3', '0.0', '22.3',
#          '0.0007285714285714286', '-18.4414032', '0.0', '0.0', '3.48',
#          '0.6999999999999997', '3.5', '72.5284032', '56.81', '0.0',
#          '85.587', '0.5595500000000001', '-13.442799999999998',
#          '36.107200000000006', '1.75', '-42.33', '0.35491132449093965',
#          '2.943', '4.880386619831485', '54.087', '0.5847', '-0.49745',
#          '628.9819494584838', '-15.018403199999998', '-73.83',
#          '0.0154289', '81.53', '2.047', '3.2463', '1.618', '-3.48',
#          '7.48', '187.35500000000002', '34.5315968', '57.03',
#          '10.862745098039214', '4.475639300043912', '69.342744',
#          '0.02856', '0.04116194284370222', '3.1999999999999997',
#          '5.4281152', '0.0', '20.10771992818671', '18.9707032',
#          '18.050541516245488', '34.10844380610413', '85.53', '3.49745',
#          '-84.473', '0.0065506291896977546', '175.57840000000002',
#          '0.0', '1.696286', '4.779464285714286', '-3.4723',
#          '18.4984032', '0.15914285714285717', '-52.973',
#          '0.5293000000000001', '8.889', '-1.0', '1.6400000000000001',
#          '-0.5293000000000001', '-81.53', '88.53', '0.0', '213.0494',
#          '9.4992016', '60.9798', '-0.21999999999999975',
#          '1.5884550719222865', '-10.7', '85.02745', '-16.9228',
#          '4.763683915561368e-05', '-36.107200000000006', '54.03',
#          '19.000953199999998', '73.83', '17.425349999999998', '84.53',
#          '170.06', '0.3', '18.9958532', '53.5023', '1.114', '11.757',
#          '102.4528', '-0.02515', '20992.156862745098', '-81.05',
#          '4551.6559', '0.5262557686399999', '404.3321299638989',
#          '-0.48', '6.222799999999999', '3.837', '-18.9707032',
#          '-85.02745', '7.798403199999999', '3.98', '0.0', '-17.42025',
#          '0.32547730244722584', '0.5277', '0.8976660682226211',
#          '0.0001342218065989883', '1.482781', '21.4028', '4.057',
#          '10.642999999999999', '0.0015898707440824666', '297.605',
#          '19.4984032', '0.13650150000000003', '6.283662477558348',
#          '3.3077', '6.1', '-0.0', '3.50255', '-0.0', '1.5', '-1.9',
#          '-0.0', '1.5', '0.0', '4.6', '0.04973070017953321', '599.536',
#          '49.550000000000004', '66.0315968', '17.450499999999998',
#          '0.18422600905743491', '15.498403199999998', '0.03025',
#          '0.009340556697179151', '50.03', '0.0014203500000000001',
#          '33345.098039215685', '0.007914285714285714', '16.9228',
#          '-84.53', '4.48', '14.7', '0.705', '7.591964285714286',
#          '-53.03', '66.4944112', '4.0077', '0.4723',
#          '17.979799999999997', '47.36171', '57.146784',
#          '-7.919999999999999', '2.0', '11.19745', '0.22343176761143124',
#          '84.473', '138.56', '0.049732142857142864',
#          '0.21999999999999975', '3.7800000000000002', '11.7',
#          '0.010149', '53.52745', '0.2008861951006727',
#          '0.02869802787152467', '36.736', '0.0', '7.0635e-05',
#          '0.09205776173285199', '0.0024732142857142856',
#          '3.2800000000000002', '107.06', '2.7230000000000003',
#          '0.029318253441426072', '-2.7800000000000002',
#          '3069.675090252708', '75.613644736', '96.10412926391382',
#          '2.7800000000000002', '7.0', '-11.19745', '11.227699999999999',
#          '338.4194', '0.000517466841023725', '52.973',
#          '0.005880277549100317', '0.49745', '-2.7230000000000003',
#          '0.0014580172716831276', '24.294285714285714', '85.0577',
#          '0.00014635994214477584', '13.93', '81.05', '-2.943', '17.0',
#          '31.279712746858163', '331.00537927295994',
#          '0.31023999999999996', '2.355331', '11.2',
#          '39.199999999999996', '15.718403199999997',
#          '1.090433409096127', '-3.2774500000000004', '1481.460684',
#          '6.2384', '19.555403199999997', '278.89840000000004', '3.0',
#          '57.51', '-81.75', '20.108303249097474', '1.9495000000000002',
#          '85.03', '0.09695', '-50.25', '0.0', '0.0', '1.5', '0.0',
#          '2.7', '-0.0', '13.442799999999998', '0.0', '-31.5',
#          '11.202549999999999', '2.0', '-3.0', '3.9523', '-16.8658',
#          '-18.9958532', '0.1317182170998471', '17.3951', '6.78',
#          '1372.549019607843', '0.0277', '67.6072', '0.48',
#          '0.0003257673762201576', '0.62954251440668', '34.8456',
#          '-0.55445', '0.209228470016813', '4.0', '5.6', '8.7114',
#          '0.2168265', '-13.922799999999999', '9.0', '0.55445', '4.537',
#          '0.0', '1.0', '-67.6072', '0.06538389688025406',
#          '7450.3541960784305', '-1.6980609575', '3.2774500000000004',
#          '-66.0315968', '20.7028', '28.622799999999998',
#          '0.008364000000000002', '1.8269600000000004', '3.98255',
#          '53.53255', '-85.0023', '152.65709156193896', '3.97745',
#          '0.01385', '3.5277', '2.2989', '3.423', '0.6428358243221526',
#          '3.0724108639254313', '-7.699999999999999', '14.48', '15.18',
#          '22.9784032', '0.05700000000000005', '0.5895232289837916',
#          '-10.642999999999999', '53.03', '-49.550000000000004',
#          '15.018403199999998', '17.9228', '-3.9523', '0.00255',
#          '0.48261155999999994', '42.515', '85.03255', '11.48',
#          '-7.798403199999999', '1.0', '1.5756031999999998', '2.0',
#          '212.78211583999996', '126.35379061371842', '-50.03', '0.2785',
#          '13.054400000000001', '5.093', '0.0', '3.4723',
#          '1932.490974729242', '7.26', '96.23', '0.0', '7.2', '13.4',
#          '4.5', '0.0', '1.5', '0.0', '2.9', '4.5', '15.1', '50.25',
#          '3.28255', '-14.142799999999998', '-11.1723',
#          '-7.219999999999999', '17.42025', '20.9228',
#          '0.9170665458873933', '-0.05700000000000005', '2.047',
#          '3.2463', '1.618', '62.314762496', '22.2784032',
#          '-3.2523000000000004', '0.02631800129391927',
#          '0.14285714285714285', '-1.0', '9.7044996',
#          '15.294285714285715', '4392.156862745098',
#          '2.8176052185269973', '-53.5023', '5.0', '10.7',
#          '196.078431372549', '53.53', '0.50255', '22.4984032',
#          '37.9968064', '0.0051', '2.21686', '17.4228', '89.01',
#          '-0.4723', '13.922799999999999', '16.8658', '-3.97745',
#          '195.13535999999996', '932.642484', '1615.434224096', '31.5',
#          '1.057', '0.02515', '64.73', '14.142799999999998',
#          '19.026103199999998', '685.8629314079423',
#          '1.5556071428571427', '0.010405380160657576',
#          '3.2523000000000004', '0.0', '2.2989', '-34.5315968',
#          '7.699999999999999', '0.203382525', '10.5821105824', '70.9528',
#          '36.421203199999994', '952.3359999999999',
#          '30.198403199999998', '0.0', '-3.49745', '0.3125',
#          '0.04442814', '1016.9845232959999', '0.557', '-17.3951',
#          '7.919999999999999', '0.0554', '-1.5756031999999998', '1.99',
#          '42.33', '2.998941550041162e-05', '11.1723',
#          '-6.222799999999999', '1.97', '0.110246', '7.219999999999999',
#          '-0.6999999999999997', '0.5', '81.75', '0.031969603048878484',
#          '26.765', '29.81621', '0.20490179936493', '18.9984032',
#          '85.0023', '104.0284032', '218.4313725490196', '0.001275',
#          '4.977942857142857', '53.557700000000004', '0.04844592816',
#          '0.00022767857142857146', '0.004578096947935368',
#          '6832.470588235293', '-15.718403199999997', '0.008925',
#          '-3.423', '0.090856', '-18.4984032', '0.0',
#          '-15.498403199999998', '44.576', '-53.52745', '22.4',
#          '18.4414032', '0.044642857142857144', '88.31', '7.2', '2.9',
#          '0.0', '-1.9', '0.0', '0.3', '0.0', '22.3',
#          '0.0007285714285714286', '-18.4414032', '0.0', '0.0', '3.48',
#          '0.6999999999999997', '3.5', '72.5284032', '56.81', '0.0',
#          '85.587', '0.5595500000000001', '-13.442799999999998',
#          '36.107200000000006', '1.75', '-42.33', '0.35491132449093965',
#          '2.943', '4.880386619831485', '54.087', '0.5847', '-0.49745',
#          '628.9819494584838', '-15.018403199999998', '-73.83',
#          '0.0154289', '81.53', '2.047', '3.2463', '1.618', '-3.48',
#          '7.48', '187.35500000000002', '34.5315968', '57.03',
#          '10.862745098039214', '4.475639300043912', '69.342744',
#          '0.02856', '0.04116194284370222', '3.1999999999999997',
#          '5.4281152', '0.0', '20.10771992818671', '18.9707032',
#          '18.050541516245488', '34.10844380610413', '85.53', '3.49745',
#          '-84.473', '0.0065506291896977546', '175.57840000000002',
#          '0.0', '1.696286', '4.779464285714286', '-3.4723',
#          '18.4984032', '0.15914285714285717', '-52.973',
#          '0.5293000000000001', '8.889', '-1.0', '1.6400000000000001',
#          '-0.5293000000000001', '-81.53', '88.53', '0.0', '213.0494',
#          '9.4992016', '60.9798', '-0.21999999999999975',
#          '1.5884550719222865', '-10.7', '85.02745', '-16.9228',
#          '4.763683915561368e-05', '-36.107200000000006', '54.03',
#          '19.000953199999998', '73.83', '17.425349999999998', '84.53',
#          '170.06', '0.3', '18.9958532', '53.5023', '1.114', '11.757',
#          '102.4528', '-0.02515', '20992.156862745098', '-81.05',
#          '4551.6559', '0.5262557686399999', '404.3321299638989',
#          '-0.48', '6.222799999999999', '3.837', '-18.9707032',
#          '-85.02745', '7.798403199999999', '3.98', '0.0', '-17.42025',
#          '0.32547730244722584', '0.5277', '0.8976660682226211',
#          '0.0001342218065989883', '1.482781', '21.4028', '4.057',
#          '10.642999999999999', '0.0015898707440824666', '297.605',
#          '19.4984032', '0.13650150000000003', '6.283662477558348',
#          '3.3077', '6.1', '-0.0', '3.50255', '-0.0', '1.5', '-1.9',
#          '-0.0', '1.5', '0.0', '4.6', '0.04973070017953321', '599.536',
#          '49.550000000000004', '66.0315968', '17.450499999999998',
#          '0.18422600905743491', '15.498403199999998', '0.03025',
#          '0.009340556697179151', '50.03', '0.0014203500000000001',
#          '33345.098039215685', '0.007914285714285714', '16.9228',
#          '-84.53', '4.48', '14.7', '0.705', '7.591964285714286',
#          '-53.03', '66.4944112', '4.0077', '0.4723',
#          '17.979799999999997', '47.36171', '57.146784',
#          '-7.919999999999999', '2.0', '11.19745', '0.22343176761143124',
#          '84.473', '138.56', '0.049732142857142864',
#          '0.21999999999999975', '3.7800000000000002', '11.7',
#          '0.010149', '53.52745', '0.2008861951006727',
#          '0.02869802787152467', '36.736', '0.0', '7.0635e-05',
#          '0.09205776173285199', '0.0024732142857142856',
#          '3.2800000000000002', '107.06', '2.7230000000000003',
#          '0.029318253441426072', '-2.7800000000000002',
#          '3069.675090252708', '75.613644736', '96.10412926391382',
#          '2.7800000000000002', '7.0', '-11.19745', '11.227699999999999',
#          '338.4194', '0.000517466841023725', '52.973',
#          '0.005880277549100317', '0.49745', '-2.7230000000000003',
#          '0.0014580172716831276', '24.294285714285714', '85.0577',
#          '0.00014635994214477584', '13.93', '81.05', '-2.943', '17.0',
#          '31.279712746858163', '331.00537927295994',
#          '0.31023999999999996', '2.355331', '11.2',
#          '39.199999999999996', '15.718403199999997',
#          '1.090433409096127', '-3.2774500000000004', '1481.460684',
#          '6.2384', '19.555403199999997', '278.89840000000004', '3.0',
#          '57.51', '-81.75', '20.108303249097474', '1.9495000000000002',
#          '85.03', '0.09695', '-50.25', '0.0', '0.0', '1.5', '0.0',
#          '2.7', '-0.0', '13.442799999999998', '0.0', '-31.5',
#          '11.202549999999999', '2.0', '-3.0', '3.9523', '-16.8658',
#          '-18.9958532', '0.1317182170998471', '17.3951', '6.78',
#          '1372.549019607843', '0.0277', '67.6072', '0.48',
#          '0.0003257673762201576', '0.62954251440668', '34.8456',
#          '-0.55445', '0.209228470016813', '4.0', '5.6', '8.7114',
#          '0.2168265', '-13.922799999999999', '9.0', '0.55445', '4.537',
#          '0.0', '1.0', '-67.6072', '0.06538389688025406',
#          '7450.3541960784305', '-1.6980609575', '3.2774500000000004',
#          '-66.0315968', '20.7028', '28.622799999999998',
#          '0.008364000000000002', '1.8269600000000004', '3.98255',
#          '53.53255', '-85.0023', '152.65709156193896', '3.97745',
#          '0.01385', '3.5277', '2.2989', '3.423', '0.6428358243221526',
#          '3.0724108639254313', '-7.699999999999999', '14.48', '15.18',
#          '22.9784032', '0.05700000000000005', '0.5895232289837916',
#          '-10.642999999999999', '53.03', '-49.550000000000004',
#          '15.018403199999998', '17.9228', '-3.9523', '0.00255',
#          '0.48261155999999994'],
#         ['Mean_cfid_bp_mult_atom_rad', 'Mean_cfid_hfus_add_bp',
#          'Mean_cfid_elec_aff_mult_voro_coord',
#          'Mean_cfid_mol_vol_subs_atom_mass', 'Mean_cfid_is_halogen',
#          'Mean_cfid_atom_mass_subs_first_ion_en', 'Mean_cfid_row',
#          'Mean_cfid_mol_vol_mult_atom_mass',
#          'Mean_cfid_voro_coord_divi_therm_cond',
#          'Mean_cfid_voro_coord_subs_mp',
#          'Mean_cfid_polzbl_mult_atom_rad', 'Mean_cfid_elec_aff_mult_X',
#          'Mean_cfid_GV', 'Mean_cfid_nfunfill',
#          'Mean_cfid_voro_coord_subs_therm_cond',
#          'Mean_cfid_mp_divi_therm_cond', 'Mean_cfid_elec_aff_add_X',
#          'Mean_cfid_mol_vol_add_bp', 'Mean_cfid_C-9', 'Mean_cfid_C-8',
#          'Mean_cfid_C-7', 'Mean_cfid_C-6', 'Mean_cfid_C-5',
#          'Mean_cfid_C-4', 'Mean_cfid_C-3', 'Mean_cfid_C-2',
#          'Mean_cfid_C-1', 'Mean_cfid_C-0', 'Mean_cfid_mp_subs_elec_aff',
#          'Mean_cfid_hfus_add_elec_aff',
#          'Mean_cfid_elec_aff_subs_first_ion_en',
#          'Mean_cfid_therm_cond_subs_mol_vol',
#          'Mean_cfid_X_subs_mol_vol', 'Mean_cfid_first_ion_en_subs_hfus',
#          'Mean_cfid_first_ion_en_add_voro_coord',
#          'Mean_cfid_first_ion_en_divi_atom_mass',
#          'Mean_cfid_atom_rad_subs_polzbl', 'Mean_cfid_me1',
#          'Mean_cfid_me3', 'Mean_cfid_me2',
#          'Mean_cfid_elec_aff_mult_atom_mass',
#          'Mean_cfid_elec_aff_add_atom_mass',
#          'Mean_cfid_therm_cond_subs_elec_aff',
#          'Mean_cfid_atom_rad_divi_atom_mass',
#          'Mean_cfid_atom_rad_divi_voro_coord', 'Mean_cfid_max_oxid_s',
#          'Mean_cfid_polzbl_mult_first_ion_en',
#          'Mean_cfid_mp_divi_voro_coord', 'Mean_cfid_mol_vol_divi_hfus',
#          'Mean_cfid_mp_divi_atom_mass', 'Mean_cfid_therm_cond_subs_mp',
#          'Mean_cfid_npvalence', 'Mean_cfid_mol_vol_subs_atom_rad',
#          'Mean_cfid_atom_rad_divi_hfus', 'Mean_cfid_mp',
#          'Mean_cfid_hfus_add_atom_rad',
#          'Mean_cfid_atom_mass_add_voro_coord',
#          'Mean_cfid_atom_mass_divi_atom_rad',
#          'Mean_cfid_hfus_divi_atom_rad', 'Mean_cfid_polzbl_mult_X',
#          'Mean_cfid_first_ion_en', 'Mean_cfid_bp_add_X',
#          'Mean_cfid_therm_cond_subs_atom_rad',
#          'Mean_cfid_first_ion_en_subs_voro_coord',
#          'Mean_cfid_first_ion_en_subs_polzbl', 'Mean_cfid_hfus_subs_X',
#          'Mean_cfid_first_ion_en_mult_mol_vol',
#          'Mean_cfid_first_ion_en_mult_mp',
#          'Mean_cfid_bp_mult_atom_mass', 'Mean_cfid_bp_subs_mp',
#          'Mean_cfid_polzbl_add_atom_rad',
#          'Mean_cfid_therm_cond_subs_hfus', 'Mean_cfid_mol_vol_add_mp',
#          'Mean_cfid_first_ion_en_subs_elec_aff',
#          'Mean_cfid_atom_mass_add_therm_cond',
#          'Mean_cfid_atom_mass_divi_therm_cond',
#          'Mean_cfid_first_ion_en_divi_mol_vol',
#          'Mean_cfid_polzbl_divi_mp',
#          'Mean_cfid_elec_aff_subs_therm_cond', 'Mean_cfid_ndunfill',
#          'Mean_cfid_op_eg', 'Mean_cfid_atom_mass_subs_mp',
#          'Mean_cfid_mol_vol_subs_voro_coord', 'Mean_cfid_jv_enp',
#          'Mean_cfid_polzbl_mult_atom_mass',
#          'Mean_cfid_first_ion_en_add_mp',
#          'Mean_cfid_first_ion_en_add_atom_mass',
#          'Mean_cfid_mol_vol_mult_bp', 'Mean_cfid_mol_vol_add_atom_mass',
#          'Mean_cfid_nfvalence', 'Mean_cfid_hfus_subs_voro_coord',
#          'Mean_cfid_voro_coord_divi_mol_vol',
#          'Mean_cfid_hfus_mult_first_ion_en',
#          'Mean_cfid_mp_mult_atom_mass', 'Mean_cfid_polzbl',
#          'Mean_cfid_therm_cond_subs_first_ion_en',
#          'Mean_cfid_mol_vol_subs_elec_aff',
#          'Mean_cfid_therm_cond_divi_atom_rad',
#          'Mean_cfid_first_ion_en_subs_atom_mass',
#          'Mean_cfid_atom_rad_mult_X', 'Mean_cfid_mp_subs_mol_vol',
#          'Mean_cfid_hfus_divi_bp', 'Mean_cfid_mol_vol_subs_therm_cond',
#          'Mean_cfid_mol_vol_subs_first_ion_en', 'Mean_cfid_oq_bg',
#          'Mean_cfid_therm_cond_mult_X', 'Mean_cfid_mol_vol_subs_X',
#          'Mean_cfid_elec_aff_subs_X', 'Mean_cfid_atom_rad',
#          'Mean_cfid_bp_subs_elec_aff',
#          'Mean_cfid_polzbl_divi_first_ion_en',
#          'Mean_cfid_mp_mult_atom_rad', 'Mean_cfid_polzbl_mult_mp',
#          'Mean_cfid_first_ion_en_divi_bp', 'Mean_cfid_atom_mass',
#          'Mean_cfid_bp_subs_therm_cond', 'Mean_cfid_bp_add_atom_mass',
#          'Mean_cfid_polzbl_divi_hfus', 'Mean_cfid_hfus_mult_atom_rad',
#          'Mean_cfid_first_ion_en_divi_voro_coord',
#          'Mean_cfid_mp_add_therm_cond', 'Mean_cfid_hfus_mult_atom_mass',
#          'Mean_cfid_hfus_divi_mol_vol', 'Mean_cfid_hfus_divi_polzbl',
#          'Mean_cfid_first_ion_en_divi_hfus',
#          'Mean_cfid_elec_aff_subs_atom_mass',
#          'Mean_cfid_hfus_mult_voro_coord', 'Mean_cfid_polzbl_subs_X',
#          'Mean_cfid_elec_aff_mult_therm_cond',
#          'Mean_cfid_atom_rad_subs_atom_mass', 'Mean_cfid_is_alkali',
#          'Mean_cfid_voro_coord_subs_atom_mass',
#          'Mean_cfid_mol_vol_mult_X', 'Mean_cfid_hfus_subs_mp',
#          'Mean_cfid_mol_vol_divi_atom_rad',
#          'Mean_cfid_atom_mass_subs_polzbl',
#          'Mean_cfid_atom_rad_divi_mol_vol', 'Mean_cfid_elec_aff_add_bp',
#          'Mean_cfid_C-13', 'Mean_cfid_C-12', 'Mean_cfid_C-11',
#          'Mean_cfid_C-10', 'Mean_cfid_C-17', 'Mean_cfid_C-16',
#          'Mean_cfid_C-15', 'Mean_cfid_C-14',
#          'Mean_cfid_hfus_divi_voro_coord',
#          'Mean_cfid_polzbl_subs_atom_mass', 'Mean_cfid_C-19',
#          'Mean_cfid_C-18', 'Mean_cfid_X_subs_atom_rad',
#          'Mean_cfid_X_subs_elec_aff', 'Mean_cfid_voro_coord',
#          'Mean_cfid_mp_add_atom_mass', 'Mean_cfid_elec_aff_add_mp',
#          'Mean_cfid_is_noble_gas', 'Mean_cfid_polzbl_add_bp',
#          'Mean_cfid_hfus_add_polzbl', 'Mean_cfid_X_subs_first_ion_en',
#          'Mean_cfid_mp_subs_first_ion_en',
#          'Mean_cfid_atom_rad_mult_voro_coord',
#          'Mean_cfid_mol_vol_subs_mp', 'Mean_cfid_atom_mass_divi_mp',
#          'Mean_cfid_voro_coord_subs_polzbl',
#          'Mean_cfid_bp_divi_first_ion_en', 'Mean_cfid_polzbl_add_mp',
#          'Mean_cfid_polzbl_add_therm_cond',
#          'Mean_cfid_hfus_subs_atom_rad',
#          'Mean_cfid_first_ion_en_divi_therm_cond',
#          'Mean_cfid_X_subs_atom_mass', 'Mean_cfid_mol_vol_subs_bp',
#          'Mean_cfid_polzbl_mult_therm_cond',
#          'Mean_cfid_bp_subs_voro_coord', 'Mean_cfid_e1', 'Mean_cfid_e3',
#          'Mean_cfid_e2', 'Mean_cfid_atom_rad_subs_X',
#          'Mean_cfid_X_add_voro_coord', 'Mean_cfid_mp_mult_voro_coord',
#          'Mean_cfid_mp_subs_atom_mass', 'Mean_cfid_mp_add_voro_coord',
#          'Mean_cfid_therm_cond_divi_hfus',
#          'Mean_cfid_bp_divi_atom_mass', 'Mean_cfid_first_ion_en_mult_X',
#          'Mean_cfid_hfus_mult_mol_vol', 'Mean_cfid_voro_coord_divi_bp',
#          'Mean_cfid_mol_vol_divi_voro_coord',
#          'Mean_cfid_atom_mass_divi_voro_coord',
#          'Mean_cfid_is_lanthanoid', 'Mean_cfid_mol_vol_divi_polzbl',
#          'Mean_cfid_atom_mass_subs_therm_cond',
#          'Mean_cfid_atom_rad_divi_therm_cond',
#          'Mean_cfid_atom_mass_divi_polzbl', 'Mean_cfid_bp_add_atom_rad',
#          'Mean_cfid_voro_coord_subs_hfus', 'Mean_cfid_polzbl_subs_bp',
#          'Mean_cfid_polzbl_divi_bp', 'Mean_cfid_elec_aff_mult_mp',
#          'Mean_cfid_ndvalence', 'Mean_cfid_atom_mass_divi_mol_vol',
#          'Mean_cfid_mp_divi_mol_vol',
#          'Mean_cfid_therm_cond_subs_voro_coord',
#          'Mean_cfid_atom_mass_subs_atom_rad',
#          'Mean_cfid_polzbl_divi_voro_coord', 'Mean_cfid_polzbl_subs_mp',
#          'Mean_cfid_polzbl_subs_therm_cond', 'Mean_cfid_KV',
#          'Mean_cfid_min_oxid_s', 'Mean_cfid_elec_aff_mult_atom_rad',
#          'Mean_cfid_therm_cond_subs_polzbl',
#          'Mean_cfid_voro_coord_subs_bp', 'Mean_cfid_bp_add_voro_coord',
#          'Mean_cfid_nsunfill', 'Mean_cfid_mp_mult_X',
#          'Mean_cfid_atom_mass_mult_atom_rad',
#          'Mean_cfid_first_ion_en_mult_voro_coord',
#          'Mean_cfid_elec_aff_subs_voro_coord', 'Mean_cfid_bp_divi_mp',
#          'Mean_cfid_atom_rad_subs_mol_vol', 'Mean_cfid_bp_subs_hfus',
#          'Mean_cfid_atom_rad_subs_first_ion_en',
#          'Mean_cfid_hfus_divi_mp', 'Mean_cfid_first_ion_en_subs_mp',
#          'Mean_cfid_mp_add_atom_rad', 'Mean_cfid_hfus_add_atom_mass',
#          'Mean_cfid_bp_subs_mol_vol', 'Mean_cfid_hfus_add_first_ion_en',
#          'Mean_cfid_bp_subs_atom_rad', 'Mean_cfid_bp_divi_atom_rad',
#          'Mean_cfid_C-26', 'Mean_cfid_atom_mass_subs_hfus',
#          'Mean_cfid_mp_subs_therm_cond',
#          'Mean_cfid_polzbl_divi_atom_rad',
#          'Mean_cfid_polzbl_add_mol_vol',
#          'Mean_cfid_first_ion_en_add_bp',
#          'Mean_cfid_hfus_subs_therm_cond', 'Mean_cfid_mp_divi_hfus',
#          'Mean_cfid_X_subs_bp', 'Mean_cfid_bp_mult_mp',
#          'Mean_cfid_atom_mass_mult_therm_cond',
#          'Mean_cfid_mol_vol_divi_therm_cond',
#          'Mean_cfid_voro_coord_subs_X',
#          'Mean_cfid_first_ion_en_subs_mol_vol',
#          'Mean_cfid_polzbl_add_elec_aff',
#          'Mean_cfid_therm_cond_subs_atom_mass',
#          'Mean_cfid_hfus_subs_bp', 'Mean_cfid_atom_mass_subs_mol_vol',
#          'Mean_cfid_X', 'Mean_cfid_is_actinoid',
#          'Mean_cfid_hfus_subs_first_ion_en',
#          'Mean_cfid_first_ion_en_divi_mp',
#          'Mean_cfid_atom_rad_add_therm_cond',
#          'Mean_cfid_atom_rad_divi_polzbl',
#          'Mean_cfid_hfus_divi_atom_mass',
#          'Mean_cfid_mp_mult_therm_cond', 'Mean_cfid_first_ion_en_add_X',
#          'Mean_cfid_polzbl_add_voro_coord',
#          'Mean_cfid_mol_vol_subs_polzbl',
#          'Mean_cfid_therm_cond_divi_first_ion_en',
#          'Mean_cfid_bp_mult_voro_coord',
#          'Mean_cfid_atom_mass_add_atom_rad', 'Mean_cfid_hfus_mult_mp',
#          'Mean_cfid_voro_coord_divi_polzbl',
#          'Mean_cfid_elec_aff_add_therm_cond', 'Mean_cfid_C-28',
#          'Mean_cfid_C-29', 'Mean_cfid_hfus_add_voro_coord',
#          'Mean_cfid_C-27', 'Mean_cfid_C-24', 'Mean_cfid_C-25',
#          'Mean_cfid_C-22', 'Mean_cfid_C-23', 'Mean_cfid_C-20',
#          'Mean_cfid_C-21', 'Mean_cfid_therm_cond_divi_polzbl',
#          'Mean_cfid_mol_vol_mult_mp', 'Mean_cfid_mp_subs_X',
#          'Mean_cfid_bp_subs_atom_mass',
#          'Mean_cfid_first_ion_en_add_therm_cond',
#          'Mean_cfid_voro_coord_divi_atom_mass',
#          'Mean_cfid_atom_mass_subs_voro_coord',
#          'Mean_cfid_hfus_add_therm_cond', 'Mean_cfid_atom_rad_divi_mp',
#          'Mean_cfid_mp_subs_voro_coord', 'Mean_cfid_hfus_mult_polzbl',
#          'Mean_cfid_bp_divi_hfus',
#          'Mean_cfid_therm_cond_divi_voro_coord',
#          'Mean_cfid_first_ion_en_subs_atom_rad',
#          'Mean_cfid_atom_rad_subs_bp', 'Mean_cfid_atom_rad_add_X',
#          'Mean_cfid_mol_vol_add_voro_coord', 'Mean_cfid_avg_ion_rad',
#          'Mean_cfid_bp_divi_mol_vol', 'Mean_cfid_atom_rad_subs_mp',
#          'Mean_cfid_atom_mass_mult_voro_coord',
#          'Mean_cfid_therm_cond_add_X',
#          'Mean_cfid_atom_rad_subs_therm_cond',
#          'Mean_cfid_polzbl_add_first_ion_en',
#          'Mean_cfid_polzbl_mult_bp',
#          'Mean_cfid_first_ion_en_mult_elec_aff',
#          'Mean_cfid_elec_aff_subs_mol_vol', 'Mean_cfid_nsvalence',
#          'Mean_cfid_mol_vol_subs_hfus', 'Mean_cfid_atom_mass_divi_bp',
#          'Mean_cfid_bp_subs_polzbl', 'Mean_cfid_bp_add_mp',
#          'Mean_cfid_polzbl_divi_mol_vol',
#          'Mean_cfid_voro_coord_subs_elec_aff',
#          'Mean_cfid_elec_aff_add_atom_rad',
#          'Mean_cfid_mol_vol_add_atom_rad', 'Mean_cfid_hfus_mult_X',
#          'Mean_cfid_mp_subs_hfus',
#          'Mean_cfid_voro_coord_divi_first_ion_en',
#          'Mean_cfid_atom_rad_divi_first_ion_en',
#          'Mean_cfid_elec_aff_mult_mol_vol', 'Mean_cfid_is_metalloid',
#          'Mean_cfid_hfus_mult_therm_cond',
#          'Mean_cfid_hfus_divi_therm_cond',
#          'Mean_cfid_therm_cond_divi_mol_vol', 'Mean_cfid_elec_aff',
#          'Mean_cfid_mp_divi_atom_rad', 'Mean_cfid_elec_aff_subs_polzbl',
#          'Mean_cfid_polzbl_divi_atom_mass',
#          'Mean_cfid_atom_rad_subs_elec_aff',
#          'Mean_cfid_bp_divi_therm_cond', 'Mean_cfid_atom_mass_mult_X',
#          'Mean_cfid_mp_divi_polzbl', 'Mean_cfid_elec_aff_subs_atom_rad',
#          'Mean_cfid_voro_coord_divi_atom_rad',
#          'Mean_cfid_hfus_subs_mol_vol',
#          'Mean_cfid_mol_vol_add_therm_cond', 'Mean_cfid_bp_mult_X',
#          'Mean_cfid_therm_cond_divi_mp', 'Mean_cfid_mp_subs_polzbl',
#          'Mean_cfid_atom_rad_divi_bp', 'Mean_cfid_atom_rad_subs_hfus',
#          'Mean_cfid_polzbl_subs_elec_aff',
#          'Mean_cfid_therm_cond_divi_atom_mass',
#          'Mean_cfid_bp_divi_voro_coord', 'Mean_cfid_bp_add_therm_cond',
#          'Mean_cfid_hfus_divi_first_ion_en',
#          'Mean_cfid_X_mult_voro_coord', 'Mean_cfid_bp_subs_X',
#          'Mean_cfid_polzbl_subs_voro_coord', 'Mean_cfid_coulmn',
#          'Mean_cfid_first_ion_en_divi_polzbl',
#          'Mean_cfid_first_ion_en_mult_atom_mass',
#          'Mean_cfid_mol_vol_mult_therm_cond',
#          'Mean_cfid_bp_mult_therm_cond', 'Mean_cfid_mol_vol',
#          'Mean_cfid_mol_vol_mult_voro_coord',
#          'Mean_cfid_atom_mass_subs_elec_aff',
#          'Mean_cfid_atom_mass_divi_first_ion_en',
#          'Mean_cfid_hfus_subs_elec_aff',
#          'Mean_cfid_first_ion_en_mult_bp',
#          'Mean_cfid_polzbl_mult_mol_vol',
#          'Mean_cfid_polzbl_add_atom_mass', 'Mean_cfid_elec_aff_mult_bp',
#          'Mean_cfid_voro_coord_subs_atom_rad', 'Mean_cfid_mp_add_X',
#          'Mean_cfid_elec_aff_subs_bp',
#          'Mean_cfid_polzbl_divi_therm_cond',
#          'Mean_cfid_polzbl_mult_voro_coord', 'Mean_cfid_bp',
#          'Mean_cfid_therm_cond_mult_voro_coord',
#          'Mean_cfid_elec_aff_subs_mp', 'Mean_cfid_C-31',
#          'Mean_cfid_C-30', 'Mean_cfid_C-33', 'Mean_cfid_C-32',
#          'Mean_cfid_C-35', 'Mean_cfid_C-34',
#          'Mean_cfid_first_ion_en_subs_X',
#          'Mean_cfid_is_transition_metal', 'Mean_cfid_mp_subs_bp',
#          'Mean_cfid_hfus_add_mol_vol', 'Mean_cfid_block',
#          'Mean_cfid_atom_rad_subs_voro_coord',
#          'Mean_cfid_X_subs_therm_cond',
#          'Mean_cfid_polzbl_subs_first_ion_en',
#          'Mean_cfid_hfus_subs_atom_mass', 'Mean_cfid_mol_vol_divi_bp',
#          'Mean_cfid_first_ion_en_subs_therm_cond',
#          'Mean_cfid_elec_aff_add_voro_coord',
#          'Mean_cfid_voro_coord_divi_hfus', 'Mean_cfid_therm_cond',
#          'Mean_cfid_bp_subs_first_ion_en',
#          'Mean_cfid_X_subs_voro_coord', 'Mean_cfid_therm_cond_divi_bp',
#          'Mean_cfid_mp_divi_bp', 'Mean_cfid_first_ion_en_divi_atom_rad',
#          'Mean_cfid_hfus_subs_polzbl', 'Mean_cfid_mol_vol_divi_mp',
#          'Mean_cfid_atom_rad_add_voro_coord',
#          'Mean_cfid_mol_vol_mult_atom_rad',
#          'Mean_cfid_first_ion_en_mult_atom_rad',
#          'Mean_cfid_hfus_mult_bp',
#          'Mean_cfid_voro_coord_subs_first_ion_en', 'Mean_cfid_Z',
#          'Mean_cfid_polzbl_subs_hfus', 'Mean_cfid_polzbl_add_X',
#          'Mean_cfid_is_alkaline', 'Mean_cfid_npunfill',
#          'Mean_cfid_first_ion_en_subs_bp',
#          'Mean_cfid_voro_coord_divi_mp',
#          'Mean_cfid_atom_mass_divi_hfus', 'Mean_cfid_oq_enp',
#          'Mean_cfid_elec_aff_subs_hfus', 'Mean_cfid_atom_mass_subs_bp',
#          'Mean_cfid_first_ion_en_add_elec_aff',
#          'Mean_cfid_first_ion_en_add_mol_vol',
#          'Mean_cfid_hfus_mult_elec_aff',
#          'Mean_cfid_polzbl_mult_elec_aff', 'Mean_cfid_hfus_add_X',
#          'Mean_cfid_hfus_add_mp', 'Mean_cfid_therm_cond_subs_bp',
#          'Mean_cfid_bp_divi_polzbl', 'Mean_cfid_X_subs_hfus',
#          'Mean_cfid_atom_rad_mult_therm_cond',
#          'Mean_cfid_therm_cond_add_voro_coord', 'Mean_cfid_mop_eg',
#          'Mean_cfid_X_subs_polzbl',
#          'Mean_cfid_mol_vol_divi_first_ion_en',
#          'Mean_cfid_mp_divi_first_ion_en',
#          'Mean_cfid_voro_coord_subs_mol_vol',
#          'Mean_cfid_elec_aff_add_mol_vol', 'Mean_cfid_mol_vol_add_X',
#          'Mean_cfid_atom_mass_add_X', 'Mean_cfid_polzbl_subs_atom_rad',
#          'Mean_cfid_mol_vol_divi_atom_mass',
#          'Mean_cfid_polzbl_subs_mol_vol', 'Mean_cfid_mp_subs_atom_rad',
#          'Mean_cfid_X_subs_mp', 'Mean_cfid_atom_mass_subs_X',
#          'Mean_cfid_first_ion_en_add_atom_rad',
#          'Mean_cfid_therm_cond_subs_X', 'Mean_cfid_hfus',
#          'Mean_cfid_first_ion_en_mult_therm_cond',
#          'Max_cfid_bp_mult_atom_rad', 'Max_cfid_hfus_add_bp',
#          'Max_cfid_elec_aff_mult_voro_coord',
#          'Max_cfid_mol_vol_subs_atom_mass', 'Max_cfid_is_halogen',
#          'Max_cfid_atom_mass_subs_first_ion_en', 'Max_cfid_row',
#          'Max_cfid_mol_vol_mult_atom_mass',
#          'Max_cfid_voro_coord_divi_therm_cond',
#          'Max_cfid_voro_coord_subs_mp', 'Max_cfid_polzbl_mult_atom_rad',
#          'Max_cfid_elec_aff_mult_X', 'Max_cfid_GV', 'Max_cfid_nfunfill',
#          'Max_cfid_voro_coord_subs_therm_cond',
#          'Max_cfid_mp_divi_therm_cond', 'Max_cfid_elec_aff_add_X',
#          'Max_cfid_mol_vol_add_bp', 'Max_cfid_C-9', 'Max_cfid_C-8',
#          'Max_cfid_C-7', 'Max_cfid_C-6', 'Max_cfid_C-5', 'Max_cfid_C-4',
#          'Max_cfid_C-3', 'Max_cfid_C-2', 'Max_cfid_C-1', 'Max_cfid_C-0',
#          'Max_cfid_mp_subs_elec_aff', 'Max_cfid_hfus_add_elec_aff',
#          'Max_cfid_elec_aff_subs_first_ion_en',
#          'Max_cfid_therm_cond_subs_mol_vol', 'Max_cfid_X_subs_mol_vol',
#          'Max_cfid_first_ion_en_subs_hfus',
#          'Max_cfid_first_ion_en_add_voro_coord',
#          'Max_cfid_first_ion_en_divi_atom_mass',
#          'Max_cfid_atom_rad_subs_polzbl', 'Max_cfid_me1',
#          'Max_cfid_me3', 'Max_cfid_me2',
#          'Max_cfid_elec_aff_mult_atom_mass',
#          'Max_cfid_elec_aff_add_atom_mass',
#          'Max_cfid_therm_cond_subs_elec_aff',
#          'Max_cfid_atom_rad_divi_atom_mass',
#          'Max_cfid_atom_rad_divi_voro_coord', 'Max_cfid_max_oxid_s',
#          'Max_cfid_polzbl_mult_first_ion_en',
#          'Max_cfid_mp_divi_voro_coord', 'Max_cfid_mol_vol_divi_hfus',
#          'Max_cfid_mp_divi_atom_mass', 'Max_cfid_therm_cond_subs_mp',
#          'Max_cfid_npvalence', 'Max_cfid_mol_vol_subs_atom_rad',
#          'Max_cfid_atom_rad_divi_hfus', 'Max_cfid_mp',
#          'Max_cfid_hfus_add_atom_rad',
#          'Max_cfid_atom_mass_add_voro_coord',
#          'Max_cfid_atom_mass_divi_atom_rad',
#          'Max_cfid_hfus_divi_atom_rad', 'Max_cfid_polzbl_mult_X',
#          'Max_cfid_first_ion_en', 'Max_cfid_bp_add_X',
#          'Max_cfid_therm_cond_subs_atom_rad',
#          'Max_cfid_first_ion_en_subs_voro_coord',
#          'Max_cfid_first_ion_en_subs_polzbl', 'Max_cfid_hfus_subs_X',
#          'Max_cfid_first_ion_en_mult_mol_vol',
#          'Max_cfid_first_ion_en_mult_mp', 'Max_cfid_bp_mult_atom_mass',
#          'Max_cfid_bp_subs_mp', 'Max_cfid_polzbl_add_atom_rad',
#          'Max_cfid_therm_cond_subs_hfus', 'Max_cfid_mol_vol_add_mp',
#          'Max_cfid_first_ion_en_subs_elec_aff',
#          'Max_cfid_atom_mass_add_therm_cond',
#          'Max_cfid_atom_mass_divi_therm_cond',
#          'Max_cfid_first_ion_en_divi_mol_vol',
#          'Max_cfid_polzbl_divi_mp', 'Max_cfid_elec_aff_subs_therm_cond',
#          'Max_cfid_ndunfill', 'Max_cfid_op_eg',
#          'Max_cfid_atom_mass_subs_mp',
#          'Max_cfid_mol_vol_subs_voro_coord', 'Max_cfid_jv_enp',
#          'Max_cfid_polzbl_mult_atom_mass',
#          'Max_cfid_first_ion_en_add_mp',
#          'Max_cfid_first_ion_en_add_atom_mass',
#          'Max_cfid_mol_vol_mult_bp', 'Max_cfid_mol_vol_add_atom_mass',
#          'Max_cfid_nfvalence', 'Max_cfid_hfus_subs_voro_coord',
#          'Max_cfid_voro_coord_divi_mol_vol',
#          'Max_cfid_hfus_mult_first_ion_en',
#          'Max_cfid_mp_mult_atom_mass', 'Max_cfid_polzbl',
#          'Max_cfid_therm_cond_subs_first_ion_en',
#          'Max_cfid_mol_vol_subs_elec_aff',
#          'Max_cfid_therm_cond_divi_atom_rad',
#          'Max_cfid_first_ion_en_subs_atom_mass',
#          'Max_cfid_atom_rad_mult_X', 'Max_cfid_mp_subs_mol_vol',
#          'Max_cfid_hfus_divi_bp', 'Max_cfid_mol_vol_subs_therm_cond',
#          'Max_cfid_mol_vol_subs_first_ion_en', 'Max_cfid_oq_bg',
#          'Max_cfid_therm_cond_mult_X', 'Max_cfid_mol_vol_subs_X',
#          'Max_cfid_elec_aff_subs_X', 'Max_cfid_atom_rad',
#          'Max_cfid_bp_subs_elec_aff',
#          'Max_cfid_polzbl_divi_first_ion_en',
#          'Max_cfid_mp_mult_atom_rad', 'Max_cfid_polzbl_mult_mp',
#          'Max_cfid_first_ion_en_divi_bp', 'Max_cfid_atom_mass',
#          'Max_cfid_bp_subs_therm_cond', 'Max_cfid_bp_add_atom_mass',
#          'Max_cfid_polzbl_divi_hfus', 'Max_cfid_hfus_mult_atom_rad',
#          'Max_cfid_first_ion_en_divi_voro_coord',
#          'Max_cfid_mp_add_therm_cond', 'Max_cfid_hfus_mult_atom_mass',
#          'Max_cfid_hfus_divi_mol_vol', 'Max_cfid_hfus_divi_polzbl',
#          'Max_cfid_first_ion_en_divi_hfus',
#          'Max_cfid_elec_aff_subs_atom_mass',
#          'Max_cfid_hfus_mult_voro_coord', 'Max_cfid_polzbl_subs_X',
#          'Max_cfid_elec_aff_mult_therm_cond',
#          'Max_cfid_atom_rad_subs_atom_mass', 'Max_cfid_is_alkali',
#          'Max_cfid_voro_coord_subs_atom_mass',
#          'Max_cfid_mol_vol_mult_X', 'Max_cfid_hfus_subs_mp',
#          'Max_cfid_mol_vol_divi_atom_rad',
#          'Max_cfid_atom_mass_subs_polzbl',
#          'Max_cfid_atom_rad_divi_mol_vol', 'Max_cfid_elec_aff_add_bp',
#          'Max_cfid_C-13', 'Max_cfid_C-12', 'Max_cfid_C-11',
#          'Max_cfid_C-10', 'Max_cfid_C-17', 'Max_cfid_C-16',
#          'Max_cfid_C-15', 'Max_cfid_C-14',
#          'Max_cfid_hfus_divi_voro_coord',
#          'Max_cfid_polzbl_subs_atom_mass', 'Max_cfid_C-19',
#          'Max_cfid_C-18', 'Max_cfid_X_subs_atom_rad',
#          'Max_cfid_X_subs_elec_aff', 'Max_cfid_voro_coord',
#          'Max_cfid_mp_add_atom_mass', 'Max_cfid_elec_aff_add_mp',
#          'Max_cfid_is_noble_gas', 'Max_cfid_polzbl_add_bp',
#          'Max_cfid_hfus_add_polzbl', 'Max_cfid_X_subs_first_ion_en',
#          'Max_cfid_mp_subs_first_ion_en',
#          'Max_cfid_atom_rad_mult_voro_coord',
#          'Max_cfid_mol_vol_subs_mp', 'Max_cfid_atom_mass_divi_mp',
#          'Max_cfid_voro_coord_subs_polzbl',
#          'Max_cfid_bp_divi_first_ion_en', 'Max_cfid_polzbl_add_mp',
#          'Max_cfid_polzbl_add_therm_cond',
#          'Max_cfid_hfus_subs_atom_rad',
#          'Max_cfid_first_ion_en_divi_therm_cond',
#          'Max_cfid_X_subs_atom_mass', 'Max_cfid_mol_vol_subs_bp',
#          'Max_cfid_polzbl_mult_therm_cond',
#          'Max_cfid_bp_subs_voro_coord', 'Max_cfid_e1', 'Max_cfid_e3',
#          'Max_cfid_e2', 'Max_cfid_atom_rad_subs_X',
#          'Max_cfid_X_add_voro_coord', 'Max_cfid_mp_mult_voro_coord',
#          'Max_cfid_mp_subs_atom_mass', 'Max_cfid_mp_add_voro_coord',
#          'Max_cfid_therm_cond_divi_hfus', 'Max_cfid_bp_divi_atom_mass',
#          'Max_cfid_first_ion_en_mult_X', 'Max_cfid_hfus_mult_mol_vol',
#          'Max_cfid_voro_coord_divi_bp',
#          'Max_cfid_mol_vol_divi_voro_coord',
#          'Max_cfid_atom_mass_divi_voro_coord', 'Max_cfid_is_lanthanoid',
#          'Max_cfid_mol_vol_divi_polzbl',
#          'Max_cfid_atom_mass_subs_therm_cond',
#          'Max_cfid_atom_rad_divi_therm_cond',
#          'Max_cfid_atom_mass_divi_polzbl', 'Max_cfid_bp_add_atom_rad',
#          'Max_cfid_voro_coord_subs_hfus', 'Max_cfid_polzbl_subs_bp',
#          'Max_cfid_polzbl_divi_bp', 'Max_cfid_elec_aff_mult_mp',
#          'Max_cfid_ndvalence', 'Max_cfid_atom_mass_divi_mol_vol',
#          'Max_cfid_mp_divi_mol_vol',
#          'Max_cfid_therm_cond_subs_voro_coord',
#          'Max_cfid_atom_mass_subs_atom_rad',
#          'Max_cfid_polzbl_divi_voro_coord', 'Max_cfid_polzbl_subs_mp',
#          'Max_cfid_polzbl_subs_therm_cond', 'Max_cfid_KV',
#          'Max_cfid_min_oxid_s', 'Max_cfid_elec_aff_mult_atom_rad',
#          'Max_cfid_therm_cond_subs_polzbl',
#          'Max_cfid_voro_coord_subs_bp', 'Max_cfid_bp_add_voro_coord',
#          'Max_cfid_nsunfill', 'Max_cfid_mp_mult_X',
#          'Max_cfid_atom_mass_mult_atom_rad',
#          'Max_cfid_first_ion_en_mult_voro_coord',
#          'Max_cfid_elec_aff_subs_voro_coord', 'Max_cfid_bp_divi_mp',
#          'Max_cfid_atom_rad_subs_mol_vol', 'Max_cfid_bp_subs_hfus',
#          'Max_cfid_atom_rad_subs_first_ion_en', 'Max_cfid_hfus_divi_mp',
#          'Max_cfid_first_ion_en_subs_mp', 'Max_cfid_mp_add_atom_rad',
#          'Max_cfid_hfus_add_atom_mass', 'Max_cfid_bp_subs_mol_vol',
#          'Max_cfid_hfus_add_first_ion_en', 'Max_cfid_bp_subs_atom_rad',
#          'Max_cfid_bp_divi_atom_rad', 'Max_cfid_C-26',
#          'Max_cfid_atom_mass_subs_hfus', 'Max_cfid_mp_subs_therm_cond',
#          'Max_cfid_polzbl_divi_atom_rad', 'Max_cfid_polzbl_add_mol_vol',
#          'Max_cfid_first_ion_en_add_bp',
#          'Max_cfid_hfus_subs_therm_cond', 'Max_cfid_mp_divi_hfus',
#          'Max_cfid_X_subs_bp', 'Max_cfid_bp_mult_mp',
#          'Max_cfid_atom_mass_mult_therm_cond',
#          'Max_cfid_mol_vol_divi_therm_cond',
#          'Max_cfid_voro_coord_subs_X',
#          'Max_cfid_first_ion_en_subs_mol_vol',
#          'Max_cfid_polzbl_add_elec_aff',
#          'Max_cfid_therm_cond_subs_atom_mass', 'Max_cfid_hfus_subs_bp',
#          'Max_cfid_atom_mass_subs_mol_vol', 'Max_cfid_X',
#          'Max_cfid_is_actinoid', 'Max_cfid_hfus_subs_first_ion_en',
#          'Max_cfid_first_ion_en_divi_mp',
#          'Max_cfid_atom_rad_add_therm_cond',
#          'Max_cfid_atom_rad_divi_polzbl',
#          'Max_cfid_hfus_divi_atom_mass', 'Max_cfid_mp_mult_therm_cond',
#          'Max_cfid_first_ion_en_add_X',
#          'Max_cfid_polzbl_add_voro_coord',
#          'Max_cfid_mol_vol_subs_polzbl',
#          'Max_cfid_therm_cond_divi_first_ion_en',
#          'Max_cfid_bp_mult_voro_coord',
#          'Max_cfid_atom_mass_add_atom_rad', 'Max_cfid_hfus_mult_mp',
#          'Max_cfid_voro_coord_divi_polzbl',
#          'Max_cfid_elec_aff_add_therm_cond', 'Max_cfid_C-28',
#          'Max_cfid_C-29', 'Max_cfid_hfus_add_voro_coord',
#          'Max_cfid_C-27', 'Max_cfid_C-24', 'Max_cfid_C-25',
#          'Max_cfid_C-22', 'Max_cfid_C-23', 'Max_cfid_C-20',
#          'Max_cfid_C-21', 'Max_cfid_therm_cond_divi_polzbl',
#          'Max_cfid_mol_vol_mult_mp', 'Max_cfid_mp_subs_X',
#          'Max_cfid_bp_subs_atom_mass',
#          'Max_cfid_first_ion_en_add_therm_cond',
#          'Max_cfid_voro_coord_divi_atom_mass',
# ...
#          'Max_cfid_mp_divi_first_ion_en',
#          'Max_cfid_voro_coord_subs_mol_vol',
#          'Max_cfid_elec_aff_add_mol_vol', 'Max_cfid_mol_vol_add_X',
#          'Max_cfid_atom_mass_add_X', 'Max_cfid_polzbl_subs_atom_rad',
#          'Max_cfid_mol_vol_divi_atom_mass',
#          'Max_cfid_polzbl_subs_mol_vol', 'Max_cfid_mp_subs_atom_rad',
#          'Max_cfid_X_subs_mp', 'Max_cfid_atom_mass_subs_X',
#          'Max_cfid_first_ion_en_add_atom_rad',
#          'Max_cfid_therm_cond_subs_X', 'Max_cfid_hfus',
#          'Max_cfid_first_ion_en_mult_therm_cond',
#          'Min_cfid_bp_mult_atom_rad', 'Min_cfid_hfus_add_bp',
#          'Min_cfid_elec_aff_mult_voro_coord',
#          'Min_cfid_mol_vol_subs_atom_mass', 'Min_cfid_is_halogen',
#          'Min_cfid_atom_mass_subs_first_ion_en', 'Min_cfid_row',
#          'Min_cfid_mol_vol_mult_atom_mass',
#          'Min_cfid_voro_coord_divi_therm_cond',
#          'Min_cfid_voro_coord_subs_mp', 'Min_cfid_polzbl_mult_atom_rad',
#          'Min_cfid_elec_aff_mult_X', 'Min_cfid_GV', 'Min_cfid_nfunfill',
#          'Min_cfid_voro_coord_subs_therm_cond',
#          'Min_cfid_mp_divi_therm_cond', 'Min_cfid_elec_aff_add_X',
#          'Min_cfid_mol_vol_add_bp', 'Min_cfid_C-9', 'Min_cfid_C-8',
#          'Min_cfid_C-7', 'Min_cfid_C-6', 'Min_cfid_C-5', 'Min_cfid_C-4',
#          'Min_cfid_C-3', 'Min_cfid_C-2', 'Min_cfid_C-1', 'Min_cfid_C-0',
#          'Min_cfid_mp_subs_elec_aff', 'Min_cfid_hfus_add_elec_aff',
#          'Min_cfid_elec_aff_subs_first_ion_en',
#          'Min_cfid_therm_cond_subs_mol_vol', 'Min_cfid_X_subs_mol_vol',
#          'Min_cfid_first_ion_en_subs_hfus',
#          'Min_cfid_first_ion_en_add_voro_coord',
#          'Min_cfid_first_ion_en_divi_atom_mass',
#          'Min_cfid_atom_rad_subs_polzbl', 'Min_cfid_me1',
#          'Min_cfid_me3', 'Min_cfid_me2',
#          'Min_cfid_elec_aff_mult_atom_mass',
#          'Min_cfid_elec_aff_add_atom_mass',
#          'Min_cfid_therm_cond_subs_elec_aff',
#          'Min_cfid_atom_rad_divi_atom_mass',
#          'Min_cfid_atom_rad_divi_voro_coord', 'Min_cfid_max_oxid_s',
#          'Min_cfid_polzbl_mult_first_ion_en',
#          'Min_cfid_mp_divi_voro_coord', 'Min_cfid_mol_vol_divi_hfus',
#          'Min_cfid_mp_divi_atom_mass', 'Min_cfid_therm_cond_subs_mp',
#          'Min_cfid_npvalence', 'Min_cfid_mol_vol_subs_atom_rad',
#          'Min_cfid_atom_rad_divi_hfus', 'Min_cfid_mp',
#          'Min_cfid_hfus_add_atom_rad',
#          'Min_cfid_atom_mass_add_voro_coord',
#          'Min_cfid_atom_mass_divi_atom_rad',
#          'Min_cfid_hfus_divi_atom_rad', 'Min_cfid_polzbl_mult_X',
#          'Min_cfid_first_ion_en', 'Min_cfid_bp_add_X',
#          'Min_cfid_therm_cond_subs_atom_rad',
#          'Min_cfid_first_ion_en_subs_voro_coord',
#          'Min_cfid_first_ion_en_subs_polzbl', 'Min_cfid_hfus_subs_X',
#          'Min_cfid_first_ion_en_mult_mol_vol',
#          'Min_cfid_first_ion_en_mult_mp', 'Min_cfid_bp_mult_atom_mass',
#          'Min_cfid_bp_subs_mp', 'Min_cfid_polzbl_add_atom_rad',
#          'Min_cfid_therm_cond_subs_hfus', 'Min_cfid_mol_vol_add_mp',
#          'Min_cfid_first_ion_en_subs_elec_aff',
#          'Min_cfid_atom_mass_add_therm_cond',
#          'Min_cfid_atom_mass_divi_therm_cond',
#          'Min_cfid_first_ion_en_divi_mol_vol',
#          'Min_cfid_polzbl_divi_mp', 'Min_cfid_elec_aff_subs_therm_cond',
#          'Min_cfid_ndunfill', 'Min_cfid_op_eg',
#          'Min_cfid_atom_mass_subs_mp',
#          'Min_cfid_mol_vol_subs_voro_coord', 'Min_cfid_jv_enp',
#          'Min_cfid_polzbl_mult_atom_mass',
#          'Min_cfid_first_ion_en_add_mp',
#          'Min_cfid_first_ion_en_add_atom_mass',
#          'Min_cfid_mol_vol_mult_bp', 'Min_cfid_mol_vol_add_atom_mass',
#          'Min_cfid_nfvalence', 'Min_cfid_hfus_subs_voro_coord',
#          'Min_cfid_voro_coord_divi_mol_vol',
#          'Min_cfid_hfus_mult_first_ion_en',
#          'Min_cfid_mp_mult_atom_mass', 'Min_cfid_polzbl',
#          'Min_cfid_therm_cond_subs_first_ion_en',
#          'Min_cfid_mol_vol_subs_elec_aff',
#          'Min_cfid_therm_cond_divi_atom_rad',
#          'Min_cfid_first_ion_en_subs_atom_mass',
#          'Min_cfid_atom_rad_mult_X', 'Min_cfid_mp_subs_mol_vol',
#          'Min_cfid_hfus_divi_bp', 'Min_cfid_mol_vol_subs_therm_cond',
#          'Min_cfid_mol_vol_subs_first_ion_en', 'Min_cfid_oq_bg',
#          'Min_cfid_therm_cond_mult_X', 'Min_cfid_mol_vol_subs_X',
#          'Min_cfid_elec_aff_subs_X', 'Min_cfid_atom_rad',
#          'Min_cfid_bp_subs_elec_aff',
#          'Min_cfid_polzbl_divi_first_ion_en',
#          'Min_cfid_mp_mult_atom_rad', 'Min_cfid_polzbl_mult_mp',
#          'Min_cfid_first_ion_en_divi_bp', 'Min_cfid_atom_mass',
#          'Min_cfid_bp_subs_therm_cond', 'Min_cfid_bp_add_atom_mass',
#          'Min_cfid_polzbl_divi_hfus', 'Min_cfid_hfus_mult_atom_rad',
#          'Min_cfid_first_ion_en_divi_voro_coord',
#          'Min_cfid_mp_add_therm_cond', 'Min_cfid_hfus_mult_atom_mass',
#          'Min_cfid_hfus_divi_mol_vol', 'Min_cfid_hfus_divi_polzbl',
#          'Min_cfid_first_ion_en_divi_hfus',
#          'Min_cfid_elec_aff_subs_atom_mass',
#          'Min_cfid_hfus_mult_voro_coord', 'Min_cfid_polzbl_subs_X',
#          'Min_cfid_elec_aff_mult_therm_cond',
#          'Min_cfid_atom_rad_subs_atom_mass', 'Min_cfid_is_alkali',
#          'Min_cfid_voro_coord_subs_atom_mass',
#          'Min_cfid_mol_vol_mult_X', 'Min_cfid_hfus_subs_mp',
#          'Min_cfid_mol_vol_divi_atom_rad',
#          'Min_cfid_atom_mass_subs_polzbl',
#          'Min_cfid_atom_rad_divi_mol_vol', 'Min_cfid_elec_aff_add_bp',
#          'Min_cfid_C-13', 'Min_cfid_C-12', 'Min_cfid_C-11',
#          'Min_cfid_C-10', 'Min_cfid_C-17', 'Min_cfid_C-16',
#          'Min_cfid_C-15', 'Min_cfid_C-14',
#          'Min_cfid_hfus_divi_voro_coord',
#          'Min_cfid_polzbl_subs_atom_mass', 'Min_cfid_C-19',
#          'Min_cfid_C-18', 'Min_cfid_X_subs_atom_rad',
#          'Min_cfid_X_subs_elec_aff', 'Min_cfid_voro_coord',
#          'Min_cfid_mp_add_atom_mass', 'Min_cfid_elec_aff_add_mp',
#          'Min_cfid_is_noble_gas', 'Min_cfid_polzbl_add_bp',
#          'Min_cfid_hfus_add_polzbl', 'Min_cfid_X_subs_first_ion_en',
#          'Min_cfid_mp_subs_first_ion_en',
#          'Min_cfid_atom_rad_mult_voro_coord',
#          'Min_cfid_mol_vol_subs_mp', 'Min_cfid_atom_mass_divi_mp',
#          'Min_cfid_voro_coord_subs_polzbl',
#          'Min_cfid_bp_divi_first_ion_en', 'Min_cfid_polzbl_add_mp',
#          'Min_cfid_polzbl_add_therm_cond',
#          'Min_cfid_hfus_subs_atom_rad',
#          'Min_cfid_first_ion_en_divi_therm_cond',
#          'Min_cfid_X_subs_atom_mass', 'Min_cfid_mol_vol_subs_bp',
#          'Min_cfid_polzbl_mult_therm_cond',
#          'Min_cfid_bp_subs_voro_coord', 'Min_cfid_e1', 'Min_cfid_e3',
#          'Min_cfid_e2', 'Min_cfid_atom_rad_subs_X',
#          'Min_cfid_X_add_voro_coord', 'Min_cfid_mp_mult_voro_coord',
#          'Min_cfid_mp_subs_atom_mass', 'Min_cfid_mp_add_voro_coord',
#          'Min_cfid_therm_cond_divi_hfus', 'Min_cfid_bp_divi_atom_mass',
#          'Min_cfid_first_ion_en_mult_X', 'Min_cfid_hfus_mult_mol_vol',
#          'Min_cfid_voro_coord_divi_bp',
#          'Min_cfid_mol_vol_divi_voro_coord',
#          'Min_cfid_atom_mass_divi_voro_coord', 'Min_cfid_is_lanthanoid',
#          'Min_cfid_mol_vol_divi_polzbl',
#          'Min_cfid_atom_mass_subs_therm_cond',
#          'Min_cfid_atom_rad_divi_therm_cond',
#          'Min_cfid_atom_mass_divi_polzbl', 'Min_cfid_bp_add_atom_rad',
#          'Min_cfid_voro_coord_subs_hfus', 'Min_cfid_polzbl_subs_bp',
#          'Min_cfid_polzbl_divi_bp', 'Min_cfid_elec_aff_mult_mp',
#          'Min_cfid_ndvalence', 'Min_cfid_atom_mass_divi_mol_vol',
#          'Min_cfid_mp_divi_mol_vol',
#          'Min_cfid_therm_cond_subs_voro_coord',
#          'Min_cfid_atom_mass_subs_atom_rad',
#          'Min_cfid_polzbl_divi_voro_coord', 'Min_cfid_polzbl_subs_mp',
#          'Min_cfid_polzbl_subs_therm_cond', 'Min_cfid_KV',
#          'Min_cfid_min_oxid_s', 'Min_cfid_elec_aff_mult_atom_rad',
#          'Min_cfid_therm_cond_subs_polzbl',
#          'Min_cfid_voro_coord_subs_bp', 'Min_cfid_bp_add_voro_coord',
#          'Min_cfid_nsunfill', 'Min_cfid_mp_mult_X',
#          'Min_cfid_atom_mass_mult_atom_rad',
#          'Min_cfid_first_ion_en_mult_voro_coord',
#          'Min_cfid_elec_aff_subs_voro_coord', 'Min_cfid_bp_divi_mp',
#          'Min_cfid_atom_rad_subs_mol_vol', 'Min_cfid_bp_subs_hfus',
#          'Min_cfid_atom_rad_subs_first_ion_en', 'Min_cfid_hfus_divi_mp',
#          'Min_cfid_first_ion_en_subs_mp', 'Min_cfid_mp_add_atom_rad',
#          'Min_cfid_hfus_add_atom_mass', 'Min_cfid_bp_subs_mol_vol',
#          'Min_cfid_hfus_add_first_ion_en', 'Min_cfid_bp_subs_atom_rad',
#          'Min_cfid_bp_divi_atom_rad', 'Min_cfid_C-26',
#          'Min_cfid_atom_mass_subs_hfus', 'Min_cfid_mp_subs_therm_cond',
#          'Min_cfid_polzbl_divi_atom_rad', 'Min_cfid_polzbl_add_mol_vol',
#          'Min_cfid_first_ion_en_add_bp',
#          'Min_cfid_hfus_subs_therm_cond', 'Min_cfid_mp_divi_hfus',
#          'Min_cfid_X_subs_bp', 'Min_cfid_bp_mult_mp',
#          'Min_cfid_atom_mass_mult_therm_cond',
#          'Min_cfid_mol_vol_divi_therm_cond',
#          'Min_cfid_voro_coord_subs_X',
#          'Min_cfid_first_ion_en_subs_mol_vol',
#          'Min_cfid_polzbl_add_elec_aff',
#          'Min_cfid_therm_cond_subs_atom_mass', 'Min_cfid_hfus_subs_bp',
#          'Min_cfid_atom_mass_subs_mol_vol', 'Min_cfid_X',
#          'Min_cfid_is_actinoid', 'Min_cfid_hfus_subs_first_ion_en',
#          'Min_cfid_first_ion_en_divi_mp',
#          'Min_cfid_atom_rad_add_therm_cond',
#          'Min_cfid_atom_rad_divi_polzbl',
#          'Min_cfid_hfus_divi_atom_mass', 'Min_cfid_mp_mult_therm_cond',
#          'Min_cfid_first_ion_en_add_X',
#          'Min_cfid_polzbl_add_voro_coord',
#          'Min_cfid_mol_vol_subs_polzbl',
#          'Min_cfid_therm_cond_divi_first_ion_en',
#          'Min_cfid_bp_mult_voro_coord',
#          'Min_cfid_atom_mass_add_atom_rad', 'Min_cfid_hfus_mult_mp',
#          'Min_cfid_voro_coord_divi_polzbl',
#          'Min_cfid_elec_aff_add_therm_cond', 'Min_cfid_C-28',
#          'Min_cfid_C-29', 'Min_cfid_hfus_add_voro_coord',
#          'Min_cfid_C-27', 'Min_cfid_C-24', 'Min_cfid_C-25',
#          'Min_cfid_C-22', 'Min_cfid_C-23', 'Min_cfid_C-20',
#          'Min_cfid_C-21', 'Min_cfid_therm_cond_divi_polzbl',
#          'Min_cfid_mol_vol_mult_mp', 'Min_cfid_mp_subs_X',
#          'Min_cfid_bp_subs_atom_mass',
#          'Min_cfid_first_ion_en_add_therm_cond',
#          'Min_cfid_voro_coord_divi_atom_mass',
#          'Min_cfid_atom_mass_subs_voro_coord',
#          'Min_cfid_hfus_add_therm_cond', 'Min_cfid_atom_rad_divi_mp',
#          'Min_cfid_mp_subs_voro_coord', 'Min_cfid_hfus_mult_polzbl',
#          'Min_cfid_bp_divi_hfus', 'Min_cfid_therm_cond_divi_voro_coord',
#          'Min_cfid_first_ion_en_subs_atom_rad',
#          'Min_cfid_atom_rad_subs_bp', 'Min_cfid_atom_rad_add_X',
#          'Min_cfid_mol_vol_add_voro_coord', 'Min_cfid_avg_ion_rad',
#          'Min_cfid_bp_divi_mol_vol', 'Min_cfid_atom_rad_subs_mp',
#          'Min_cfid_atom_mass_mult_voro_coord',
#          'Min_cfid_therm_cond_add_X',
#          'Min_cfid_atom_rad_subs_therm_cond',
#          'Min_cfid_polzbl_add_first_ion_en', 'Min_cfid_polzbl_mult_bp',
#          'Min_cfid_first_ion_en_mult_elec_aff',
#          'Min_cfid_elec_aff_subs_mol_vol', 'Min_cfid_nsvalence',
#          'Min_cfid_mol_vol_subs_hfus', 'Min_cfid_atom_mass_divi_bp',
#          'Min_cfid_bp_subs_polzbl', 'Min_cfid_bp_add_mp',
#          'Min_cfid_polzbl_divi_mol_vol',
#          'Min_cfid_voro_coord_subs_elec_aff',
#          'Min_cfid_elec_aff_add_atom_rad',
#          'Min_cfid_mol_vol_add_atom_rad', 'Min_cfid_hfus_mult_X',
#          'Min_cfid_mp_subs_hfus',
#          'Min_cfid_voro_coord_divi_first_ion_en',
#          'Min_cfid_atom_rad_divi_first_ion_en',
#          'Min_cfid_elec_aff_mult_mol_vol', 'Min_cfid_is_metalloid',
#          'Min_cfid_hfus_mult_therm_cond',
#          'Min_cfid_hfus_divi_therm_cond',
#          'Min_cfid_therm_cond_divi_mol_vol', 'Min_cfid_elec_aff',
#          'Min_cfid_mp_divi_atom_rad', 'Min_cfid_elec_aff_subs_polzbl',
#          'Min_cfid_polzbl_divi_atom_mass',
#          'Min_cfid_atom_rad_subs_elec_aff',
#          'Min_cfid_bp_divi_therm_cond', 'Min_cfid_atom_mass_mult_X',
#          'Min_cfid_mp_divi_polzbl', 'Min_cfid_elec_aff_subs_atom_rad',
#          'Min_cfid_voro_coord_divi_atom_rad',
#          'Min_cfid_hfus_subs_mol_vol',
#          'Min_cfid_mol_vol_add_therm_cond', 'Min_cfid_bp_mult_X',
#          'Min_cfid_therm_cond_divi_mp', 'Min_cfid_mp_subs_polzbl',
#          'Min_cfid_atom_rad_divi_bp', 'Min_cfid_atom_rad_subs_hfus',
#          'Min_cfid_polzbl_subs_elec_aff',
#          'Min_cfid_therm_cond_divi_atom_mass',
#          'Min_cfid_bp_divi_voro_coord', 'Min_cfid_bp_add_therm_cond',
#          'Min_cfid_hfus_divi_first_ion_en',
#          'Min_cfid_X_mult_voro_coord', 'Min_cfid_bp_subs_X',
#          'Min_cfid_polzbl_subs_voro_coord', 'Min_cfid_coulmn',
#          'Min_cfid_first_ion_en_divi_polzbl',
#          'Min_cfid_first_ion_en_mult_atom_mass',
#          'Min_cfid_mol_vol_mult_therm_cond',
#          'Min_cfid_bp_mult_therm_cond', 'Min_cfid_mol_vol',
#          'Min_cfid_mol_vol_mult_voro_coord',
#          'Min_cfid_atom_mass_subs_elec_aff',
#          'Min_cfid_atom_mass_divi_first_ion_en',
#          'Min_cfid_hfus_subs_elec_aff', 'Min_cfid_first_ion_en_mult_bp',
#          'Min_cfid_polzbl_mult_mol_vol',
#          'Min_cfid_polzbl_add_atom_mass', 'Min_cfid_elec_aff_mult_bp',
#          'Min_cfid_voro_coord_subs_atom_rad', 'Min_cfid_mp_add_X',
#          'Min_cfid_elec_aff_subs_bp', 'Min_cfid_polzbl_divi_therm_cond',
#          'Min_cfid_polzbl_mult_voro_coord', 'Min_cfid_bp',
#          'Min_cfid_therm_cond_mult_voro_coord',
#          'Min_cfid_elec_aff_subs_mp', 'Min_cfid_C-31', 'Min_cfid_C-30',
#          'Min_cfid_C-33', 'Min_cfid_C-32', 'Min_cfid_C-35',
#          'Min_cfid_C-34', 'Min_cfid_first_ion_en_subs_X',
#          'Min_cfid_is_transition_metal', 'Min_cfid_mp_subs_bp',
#          'Min_cfid_hfus_add_mol_vol', 'Min_cfid_block',
#          'Min_cfid_atom_rad_subs_voro_coord',
#          'Min_cfid_X_subs_therm_cond',
#          'Min_cfid_polzbl_subs_first_ion_en',
#          'Min_cfid_hfus_subs_atom_mass', 'Min_cfid_mol_vol_divi_bp',
#          'Min_cfid_first_ion_en_subs_therm_cond',
#          'Min_cfid_elec_aff_add_voro_coord',
#          'Min_cfid_voro_coord_divi_hfus', 'Min_cfid_therm_cond',
#          'Min_cfid_bp_subs_first_ion_en', 'Min_cfid_X_subs_voro_coord',
#          'Min_cfid_therm_cond_divi_bp', 'Min_cfid_mp_divi_bp',
#          'Min_cfid_first_ion_en_divi_atom_rad',
#          'Min_cfid_hfus_subs_polzbl', 'Min_cfid_mol_vol_divi_mp',
#          'Min_cfid_atom_rad_add_voro_coord',
#          'Min_cfid_mol_vol_mult_atom_rad',
#          'Min_cfid_first_ion_en_mult_atom_rad', 'Min_cfid_hfus_mult_bp',
#          'Min_cfid_voro_coord_subs_first_ion_en', 'Min_cfid_Z',
#          'Min_cfid_polzbl_subs_hfus', 'Min_cfid_polzbl_add_X',
#          'Min_cfid_is_alkaline', 'Min_cfid_npunfill',
#          'Min_cfid_first_ion_en_subs_bp', 'Min_cfid_voro_coord_divi_mp',
#          'Min_cfid_atom_mass_divi_hfus', 'Min_cfid_oq_enp',
#          'Min_cfid_elec_aff_subs_hfus', 'Min_cfid_atom_mass_subs_bp',
#          'Min_cfid_first_ion_en_add_elec_aff',
#          'Min_cfid_first_ion_en_add_mol_vol',
#          'Min_cfid_hfus_mult_elec_aff', 'Min_cfid_polzbl_mult_elec_aff',
#          'Min_cfid_hfus_add_X', 'Min_cfid_hfus_add_mp',
#          'Min_cfid_therm_cond_subs_bp', 'Min_cfid_bp_divi_polzbl',
#          'Min_cfid_X_subs_hfus', 'Min_cfid_atom_rad_mult_therm_cond',
#          'Min_cfid_therm_cond_add_voro_coord', 'Min_cfid_mop_eg',
#          'Min_cfid_X_subs_polzbl', 'Min_cfid_mol_vol_divi_first_ion_en',
#          'Min_cfid_mp_divi_first_ion_en',
#          'Min_cfid_voro_coord_subs_mol_vol',
#          'Min_cfid_elec_aff_add_mol_vol', 'Min_cfid_mol_vol_add_X',
#          'Min_cfid_atom_mass_add_X', 'Min_cfid_polzbl_subs_atom_rad',
#          'Min_cfid_mol_vol_divi_atom_mass',
#          'Min_cfid_polzbl_subs_mol_vol', 'Min_cfid_mp_subs_atom_rad',
#          'Min_cfid_X_subs_mp', 'Min_cfid_atom_mass_subs_X',
#          'Min_cfid_first_ion_en_add_atom_rad',
#          'Min_cfid_therm_cond_subs_X', 'Min_cfid_hfus',
#          'Min_cfid_first_ion_en_mult_therm_cond']]], dtype='<U38')

# %% [markdown]
# ### Names of the 1557 chemical force-field inspired descriptors
#
# ### Further breakdown here:
#     https://jarvis-tools.readthedocs.io/en/master/autoapi/jarvis/ai/descriptors/cfid/index.html

# %%
import jarvis
jarvis.ai.descriptors.cfid.feat_names()
# Out:
# ['bp_mult_atom_rad',
#  'hfus_add_bp',
#  'elec_aff_mult_voro_coord',
#  'mol_vol_subs_atom_mass',
#  'is_halogen',
#  'atom_mass_subs_first_ion_en',
#  'row',
#  'mol_vol_mult_atom_mass',
#  'voro_coord_divi_therm_cond',
#  'voro_coord_subs_mp',
#  'polzbl_mult_atom_rad',
#  'elec_aff_mult_X',
#  'GV',
#  'nfunfill',
#  'voro_coord_subs_therm_cond',
#  'mp_divi_therm_cond',
#  'elec_aff_add_X',
#  'mol_vol_add_bp',
#  'C-9',
#  'C-8',
#  'C-7',
#  'C-6',
#  'C-5',
#  'C-4',
#  'C-3',
#  'C-2',
#  'C-1',
#  'C-0',
#  'mp_subs_elec_aff',
#  'hfus_add_elec_aff',
#  'elec_aff_subs_first_ion_en',
#  'therm_cond_subs_mol_vol',
#  'X_subs_mol_vol',
#  'first_ion_en_subs_hfus',
#  'first_ion_en_add_voro_coord',
#  'first_ion_en_divi_atom_mass',
#  'atom_rad_subs_polzbl',
#  'me1',
#  'me3',
#  'me2',
#  'elec_aff_mult_atom_mass',
#  'elec_aff_add_atom_mass',
#  'therm_cond_subs_elec_aff',
#  'atom_rad_divi_atom_mass',
#  'atom_rad_divi_voro_coord',
#  'max_oxid_s',
#  'polzbl_mult_first_ion_en',
#  'mp_divi_voro_coord',
#  'mol_vol_divi_hfus',
#  'mp_divi_atom_mass',
#  'therm_cond_subs_mp',
#  'npvalence',
#  'mol_vol_subs_atom_rad',
#  'atom_rad_divi_hfus',
#  'mp',
#  'hfus_add_atom_rad',
#  'atom_mass_add_voro_coord',
#  'atom_mass_divi_atom_rad',
#  'hfus_divi_atom_rad',
#  'polzbl_mult_X',
#  'first_ion_en',
#  'bp_add_X',
#  'therm_cond_subs_atom_rad',
#  'first_ion_en_subs_voro_coord',
#  'first_ion_en_subs_polzbl',
#  'hfus_subs_X',
#  'first_ion_en_mult_mol_vol',
#  'first_ion_en_mult_mp',
#  'bp_mult_atom_mass',
#  'bp_subs_mp',
#  'polzbl_add_atom_rad',
#  'therm_cond_subs_hfus',
#  'mol_vol_add_mp',
#  'first_ion_en_subs_elec_aff',
#  'atom_mass_add_therm_cond',
#  'atom_mass_divi_therm_cond',
#  'first_ion_en_divi_mol_vol',
#  'polzbl_divi_mp',
#  'elec_aff_subs_therm_cond',
#  'ndunfill',
#  'op_eg',
#  'atom_mass_subs_mp',
#  'mol_vol_subs_voro_coord',
#  'jv_enp',
#  'polzbl_mult_atom_mass',
#  'first_ion_en_add_mp',
#  'first_ion_en_add_atom_mass',
#  'mol_vol_mult_bp',
#  'mol_vol_add_atom_mass',
#  'nfvalence',
#  'hfus_subs_voro_coord',
#  'voro_coord_divi_mol_vol',
#  'hfus_mult_first_ion_en',
#  'mp_mult_atom_mass',
#  'polzbl',
#  'therm_cond_subs_first_ion_en',
#  'mol_vol_subs_elec_aff',
#  'therm_cond_divi_atom_rad',
#  'first_ion_en_subs_atom_mass',
#  'atom_rad_mult_X',
#  'mp_subs_mol_vol',
#  'hfus_divi_bp',
#  'mol_vol_subs_therm_cond',
#  'mol_vol_subs_first_ion_en',
#  'oq_bg',
#  'therm_cond_mult_X',
#  'mol_vol_subs_X',
#  'elec_aff_subs_X',
#  'atom_rad',
#  'bp_subs_elec_aff',
#  'polzbl_divi_first_ion_en',
#  'mp_mult_atom_rad',
#  'polzbl_mult_mp',
#  'first_ion_en_divi_bp',
#  'atom_mass',
#  'bp_subs_therm_cond',
#  'bp_add_atom_mass',
#  'polzbl_divi_hfus',
#  'hfus_mult_atom_rad',
#  'first_ion_en_divi_voro_coord',
#  'mp_add_therm_cond',
#  'hfus_mult_atom_mass',
#  'hfus_divi_mol_vol',
#  'hfus_divi_polzbl',
#  'first_ion_en_divi_hfus',
#  'elec_aff_subs_atom_mass',
#  'hfus_mult_voro_coord',
#  'polzbl_subs_X',
#  'elec_aff_mult_therm_cond',
#  'atom_rad_subs_atom_mass',
#  'is_alkali',
#  'voro_coord_subs_atom_mass',
#  'mol_vol_mult_X',
#  'hfus_subs_mp',
#  'mol_vol_divi_atom_rad',
#  'atom_mass_subs_polzbl',
#  'atom_rad_divi_mol_vol',
#  'elec_aff_add_bp',
#  'C-13',
#  'C-12',
#  'C-11',
#  'C-10',
#  'C-17',
#  'C-16',
#  'C-15',
#  'C-14',
#  'hfus_divi_voro_coord',
#  'polzbl_subs_atom_mass',
#  'C-19',
#  'C-18',
#  'X_subs_atom_rad',
#  'X_subs_elec_aff',
#  'voro_coord',
#  'mp_add_atom_mass',
#  'elec_aff_add_mp',
#  'is_noble_gas',
#  'polzbl_add_bp',
#  'hfus_add_polzbl',
#  'X_subs_first_ion_en',
#  'mp_subs_first_ion_en',
#  'atom_rad_mult_voro_coord',
#  'mol_vol_subs_mp',
#  'atom_mass_divi_mp',
#  'voro_coord_subs_polzbl',
#  'bp_divi_first_ion_en',
#  'polzbl_add_mp',
#  'polzbl_add_therm_cond',
#  'hfus_subs_atom_rad',
#  'first_ion_en_divi_therm_cond',
#  'X_subs_atom_mass',
#  'mol_vol_subs_bp',
#  'polzbl_mult_therm_cond',
#  'bp_subs_voro_coord',
#  'e1',
#  'e3',
#  'e2',
#  'atom_rad_subs_X',
#  'X_add_voro_coord',
#  'mp_mult_voro_coord',
#  'mp_subs_atom_mass',
#  'mp_add_voro_coord',
#  'therm_cond_divi_hfus',
#  'bp_divi_atom_mass',
#  'first_ion_en_mult_X',
#  'hfus_mult_mol_vol',
#  'voro_coord_divi_bp',
#  'mol_vol_divi_voro_coord',
#  'atom_mass_divi_voro_coord',
#  'is_lanthanoid',
#  'mol_vol_divi_polzbl',
#  'atom_mass_subs_therm_cond',
#  'atom_rad_divi_therm_cond',
#  'atom_mass_divi_polzbl',
#  'bp_add_atom_rad',
#  'voro_coord_subs_hfus',
#  'polzbl_subs_bp',
#  'polzbl_divi_bp',
#  'elec_aff_mult_mp',
#  'ndvalence',
#  'atom_mass_divi_mol_vol',
#  'mp_divi_mol_vol',
#  'therm_cond_subs_voro_coord',
#  'atom_mass_subs_atom_rad',
#  'polzbl_divi_voro_coord',
#  'polzbl_subs_mp',
#  'polzbl_subs_therm_cond',
#  'KV',
#  'min_oxid_s',
#  'elec_aff_mult_atom_rad',
#  'therm_cond_subs_polzbl',
#  'voro_coord_subs_bp',
#  'bp_add_voro_coord',
#  'nsunfill',
#  'mp_mult_X',
#  'atom_mass_mult_atom_rad',
#  'first_ion_en_mult_voro_coord',
#  'elec_aff_subs_voro_coord',
#  'bp_divi_mp',
#  'atom_rad_subs_mol_vol',
#  'bp_subs_hfus',
#  'atom_rad_subs_first_ion_en',
#  'hfus_divi_mp',
#  'first_ion_en_subs_mp',
#  'mp_add_atom_rad',
#  'hfus_add_atom_mass',
#  'bp_subs_mol_vol',
#  'hfus_add_first_ion_en',
#  'bp_subs_atom_rad',
#  'bp_divi_atom_rad',
#  'C-26',
#  'atom_mass_subs_hfus',
#  'mp_subs_therm_cond',
#  'polzbl_divi_atom_rad',
#  'polzbl_add_mol_vol',
#  'first_ion_en_add_bp',
#  'hfus_subs_therm_cond',
#  'mp_divi_hfus',
#  'X_subs_bp',
#  'bp_mult_mp',
#  'atom_mass_mult_therm_cond',
#  'mol_vol_divi_therm_cond',
#  'voro_coord_subs_X',
#  'first_ion_en_subs_mol_vol',
#  'polzbl_add_elec_aff',
#  'therm_cond_subs_atom_mass',
#  'hfus_subs_bp',
#  'atom_mass_subs_mol_vol',
#  'X',
#  'is_actinoid',
#  'hfus_subs_first_ion_en',
#  'first_ion_en_divi_mp',
#  'atom_rad_add_therm_cond',
#  'atom_rad_divi_polzbl',
#  'hfus_divi_atom_mass',
#  'mp_mult_therm_cond',
#  'first_ion_en_add_X',
#  'polzbl_add_voro_coord',
#  'mol_vol_subs_polzbl',
#  'therm_cond_divi_first_ion_en',
#  'bp_mult_voro_coord',
#  'atom_mass_add_atom_rad',
#  'hfus_mult_mp',
#  'voro_coord_divi_polzbl',
#  'elec_aff_add_therm_cond',
#  'C-28',
#  'C-29',
#  'hfus_add_voro_coord',
#  'C-27',
#  'C-24',
#  'C-25',
#  'C-22',
#  'C-23',
#  'C-20',
#  'C-21',
#  'therm_cond_divi_polzbl',
#  'mol_vol_mult_mp',
#  'mp_subs_X',
#  'bp_subs_atom_mass',
#  'first_ion_en_add_therm_cond',
#  'voro_coord_divi_atom_mass',
#  'atom_mass_subs_voro_coord',
#  'hfus_add_therm_cond',
#  'atom_rad_divi_mp',
#  'mp_subs_voro_coord',
#  'hfus_mult_polzbl',
#  'bp_divi_hfus',
#  'therm_cond_divi_voro_coord',
#  'first_ion_en_subs_atom_rad',
#  'atom_rad_subs_bp',
#  'atom_rad_add_X',
#  'mol_vol_add_voro_coord',
#  'avg_ion_rad',
#  'bp_divi_mol_vol',
#  'atom_rad_subs_mp',
#  'atom_mass_mult_voro_coord',
#  'therm_cond_add_X',
#  'atom_rad_subs_therm_cond',
#  'polzbl_add_first_ion_en',
#  'polzbl_mult_bp',
#  'first_ion_en_mult_elec_aff',
#  'elec_aff_subs_mol_vol',
#  'nsvalence',
#  'mol_vol_subs_hfus',
#  'atom_mass_divi_bp',
#  'bp_subs_polzbl',
#  'bp_add_mp',
#  'polzbl_divi_mol_vol',
#  'voro_coord_subs_elec_aff',
#  'elec_aff_add_atom_rad',
#  'mol_vol_add_atom_rad',
#  'hfus_mult_X',
#  'mp_subs_hfus',
#  'voro_coord_divi_first_ion_en',
#  'atom_rad_divi_first_ion_en',
#  'elec_aff_mult_mol_vol',
#  'is_metalloid',
#  'hfus_mult_therm_cond',
#  'hfus_divi_therm_cond',
#  'therm_cond_divi_mol_vol',
#  'elec_aff',
#  'mp_divi_atom_rad',
#  'elec_aff_subs_polzbl',
#  'polzbl_divi_atom_mass',
#  'atom_rad_subs_elec_aff',
#  'bp_divi_therm_cond',
#  'atom_mass_mult_X',
#  'mp_divi_polzbl',
#  'elec_aff_subs_atom_rad',
#  'voro_coord_divi_atom_rad',
#  'hfus_subs_mol_vol',
#  'mol_vol_add_therm_cond',
#  'bp_mult_X',
#  'therm_cond_divi_mp',
#  'mp_subs_polzbl',
#  'atom_rad_divi_bp',
#  'atom_rad_subs_hfus',
#  'polzbl_subs_elec_aff',
#  'therm_cond_divi_atom_mass',
#  'bp_divi_voro_coord',
#  'bp_add_therm_cond',
#  'hfus_divi_first_ion_en',
#  'X_mult_voro_coord',
#  'bp_subs_X',
#  'polzbl_subs_voro_coord',
#  'coulmn',
#  'first_ion_en_divi_polzbl',
#  'first_ion_en_mult_atom_mass',
#  'mol_vol_mult_therm_cond',
#  'bp_mult_therm_cond',
#  'mol_vol',
#  'mol_vol_mult_voro_coord',
#  'atom_mass_subs_elec_aff',
#  'atom_mass_divi_first_ion_en',
#  'hfus_subs_elec_aff',
#  'first_ion_en_mult_bp',
#  'polzbl_mult_mol_vol',
#  'polzbl_add_atom_mass',
#  'elec_aff_mult_bp',
#  'voro_coord_subs_atom_rad',
#  'mp_add_X',
#  'elec_aff_subs_bp',
#  'polzbl_divi_therm_cond',
#  'polzbl_mult_voro_coord',
#  'bp',
#  'therm_cond_mult_voro_coord',
#  'elec_aff_subs_mp',
#  'C-31',
#  'C-30',
#  'C-33',
#  'C-32',
#  'C-35',
#  'C-34',
#  'first_ion_en_subs_X',
#  'is_transition_metal',
#  'mp_subs_bp',
#  'hfus_add_mol_vol',
#  'block',
#  'atom_rad_subs_voro_coord',
#  'X_subs_therm_cond',
#  'polzbl_subs_first_ion_en',
#  'hfus_subs_atom_mass',
#  'mol_vol_divi_bp',
#  'first_ion_en_subs_therm_cond',
#  'elec_aff_add_voro_coord',
#  'voro_coord_divi_hfus',
#  'therm_cond',
#  'bp_subs_first_ion_en',
#  'X_subs_voro_coord',
#  'therm_cond_divi_bp',
#  'mp_divi_bp',
#  'first_ion_en_divi_atom_rad',
#  'hfus_subs_polzbl',
#  'mol_vol_divi_mp',
#  'atom_rad_add_voro_coord',
#  'mol_vol_mult_atom_rad',
#  'first_ion_en_mult_atom_rad',
#  'hfus_mult_bp',
#  'voro_coord_subs_first_ion_en',
#  'Z',
#  'polzbl_subs_hfus',
#  'polzbl_add_X',
#  'is_alkaline',
#  'npunfill',
#  'first_ion_en_subs_bp',
#  'voro_coord_divi_mp',
#  'atom_mass_divi_hfus',
#  'oq_enp',
#  'elec_aff_subs_hfus',
#  'atom_mass_subs_bp',
#  'first_ion_en_add_elec_aff',
#  'first_ion_en_add_mol_vol',
#  'hfus_mult_elec_aff',
#  'polzbl_mult_elec_aff',
#  'hfus_add_X',
#  'hfus_add_mp',
#  'therm_cond_subs_bp',
#  'bp_divi_polzbl',
#  'X_subs_hfus',
#  'atom_rad_mult_therm_cond',
#  'therm_cond_add_voro_coord',
#  'mop_eg',
#  'X_subs_polzbl',
#  'mol_vol_divi_first_ion_en',
#  'mp_divi_first_ion_en',
#  'voro_coord_subs_mol_vol',
#  'elec_aff_add_mol_vol',
#  'mol_vol_add_X',
#  'atom_mass_add_X',
#  'polzbl_subs_atom_rad',
#  'mol_vol_divi_atom_mass',
#  'polzbl_subs_mol_vol',
#  'mp_subs_atom_rad',
#  'X_subs_mp',
#  'atom_mass_subs_X',
#  'first_ion_en_add_atom_rad',
#  'therm_cond_subs_X',
#  'hfus',
#  'first_ion_en_mult_therm_cond',
#  'cell_0',
#  'cell_1',
#  'cell_2',
#  'cell_3',
#  'mean_chg_0',
#  'mean_chg_1',
#  'mean_chg_2',
#  'mean_chg_3',
#  'mean_chg_4',
#  'mean_chg_5',
#  'mean_chg_6',
#  'mean_chg_7',
#  'mean_chg_8',
#  'mean_chg_9',
#  'mean_chg_10',
#  'mean_chg_11',
#  'mean_chg_12',
#  'mean_chg_13',
#  'mean_chg_14',
#  'mean_chg_15',
#  'mean_chg_16',
#  'mean_chg_17',
#  'mean_chg_18',
#  'mean_chg_19',
#  'mean_chg_20',
#  'mean_chg_21',
#  'mean_chg_22',
#  'mean_chg_23',
#  'mean_chg_24',
#  'mean_chg_25',
#  'mean_chg_26',
#  'mean_chg_27',
#  'mean_chg_28',
#  'mean_chg_29',
#  'mean_chg_30',
#  'mean_chg_31',
#  'mean_chg_32',
#  'mean_chg_33',
#  'mean_chg_34',
#  'mean_chg_35',
#  'mean_chg_36',
#  'mean_chg_37',
#  'mean_chg_38',
#  'mean_chg_39',
#  'mean_chg_40',
#  'mean_chg_41',
#  'mean_chg_42',
#  'mean_chg_43',
#  'mean_chg_44',
#  'mean_chg_45',
#  'mean_chg_46',
#  'mean_chg_47',
#  'mean_chg_48',
#  'mean_chg_49',
#  'mean_chg_50',
#  'mean_chg_51',
#  'mean_chg_52',
#  'mean_chg_53',
#  'mean_chg_54',
#  'mean_chg_55',
#  'mean_chg_56',
#  'mean_chg_57',
#  'mean_chg_58',
#  'mean_chg_59',
#  'mean_chg_60',
#  'mean_chg_61',
#  'mean_chg_62',
#  'mean_chg_63',
#  'mean_chg_64',
#  'mean_chg_65',
#  'mean_chg_66',
#  'mean_chg_67',
#  'mean_chg_68',
#  'mean_chg_69',
#  'mean_chg_70',
#  'mean_chg_71',
#  'mean_chg_72',
#  'mean_chg_73',
#  'mean_chg_74',
#  'mean_chg_75',
#  'mean_chg_76',
#  'mean_chg_77',
#  'mean_chg_78',
#  'mean_chg_79',
#  'mean_chg_80',
#  'mean_chg_81',
#  'mean_chg_82',
#  'mean_chg_83',
#  'mean_chg_84',
#  'mean_chg_85',
#  'mean_chg_86',
#  'mean_chg_87',
#  'mean_chg_88',
#  'mean_chg_89',
#  'mean_chg_90',
#  'mean_chg_91',
#  'mean_chg_92',
#  'mean_chg_93',
#  'mean_chg_94',
#  'mean_chg_95',
#  'mean_chg_96',
#  'mean_chg_97',
#  'mean_chg_98',
#  'mean_chg_99',
#  'mean_chg_100',
#  'mean_chg_101',
#  'mean_chg_102',
#  'mean_chg_103',
#  'mean_chg_104',
#  'mean_chg_105',
#  'mean_chg_106',
#  'mean_chg_107',
#  'mean_chg_108',
#  'mean_chg_109',
#  'mean_chg_110',
#  'mean_chg_111',
#  'mean_chg_112',
#  'mean_chg_113',
#  'mean_chg_114',
#  'mean_chg_115',
#  'mean_chg_116',
#  'mean_chg_117',
#  'mean_chg_118',
#  'mean_chg_119',
#  'mean_chg_120',
#  'mean_chg_121',
#  'mean_chg_122',
#  'mean_chg_123',
#  'mean_chg_124',
#  'mean_chg_125',
#  'mean_chg_126',
#  'mean_chg_127',
#  'mean_chg_128',
#  'mean_chg_129',
#  'mean_chg_130',
#  'mean_chg_131',
#  'mean_chg_132',
#  'mean_chg_133',
#  'mean_chg_134',
#  'mean_chg_135',
#  'mean_chg_136',
#  'mean_chg_137',
#  'mean_chg_138',
#  'mean_chg_139',
#  'mean_chg_140',
#  'mean_chg_141',
#  'mean_chg_142',
#  'mean_chg_143',
#  'mean_chg_144',
#  'mean_chg_145',
#  'mean_chg_146',
#  'mean_chg_147',
#  'mean_chg_148',
#  'mean_chg_149',
#  'mean_chg_150',
#  'mean_chg_151',
#  'mean_chg_152',
#  'mean_chg_153',
#  'mean_chg_154',
#  'mean_chg_155',
#  'mean_chg_156',
#  'mean_chg_157',
#  'mean_chg_158',
#  'mean_chg_159',
#  'mean_chg_160',
#  'mean_chg_161',
#  'mean_chg_162',
#  'mean_chg_163',
#  'mean_chg_164',
#  'mean_chg_165',
#  'mean_chg_166',
#  'mean_chg_167',
#  'mean_chg_168',
#  'mean_chg_169',
#  'mean_chg_170',
#  'mean_chg_171',
#  'mean_chg_172',
#  'mean_chg_173',
#  'mean_chg_174',
#  'mean_chg_175',
#  'mean_chg_176',
#  'mean_chg_177',
#  'mean_chg_178',
#  'mean_chg_179',
#  'mean_chg_180',
#  'mean_chg_181',
#  'mean_chg_182',
#  'mean_chg_183',
#  'mean_chg_184',
#  'mean_chg_185',
#  'mean_chg_186',
#  'mean_chg_187',
#  'mean_chg_188',
#  'mean_chg_189',
#  'mean_chg_190',
#  'mean_chg_191',
#  'mean_chg_192',
#  'mean_chg_193',
#  'mean_chg_194',
#  'mean_chg_195',
#  'mean_chg_196',
#  'mean_chg_197',
#  'mean_chg_198',
#  'mean_chg_199',
#  'mean_chg_200',
#  'mean_chg_201',
#  'mean_chg_202',
#  'mean_chg_203',
#  'mean_chg_204',
#  'mean_chg_205',
#  'mean_chg_206',
#  'mean_chg_207',
#  'mean_chg_208',
#  'mean_chg_209',
#  'mean_chg_210',
#  'mean_chg_211',
#  'mean_chg_212',
#  'mean_chg_213',
#  'mean_chg_214',
#  'mean_chg_215',
#  'mean_chg_216',
#  'mean_chg_217',
#  'mean_chg_218',
#  'mean_chg_219',
#  'mean_chg_220',
#  'mean_chg_221',
#  'mean_chg_222',
#  'mean_chg_223',
#  'mean_chg_224',
#  'mean_chg_225',
#  'mean_chg_226',
#  'mean_chg_227',
#  'mean_chg_228',
#  'mean_chg_229',
#  'mean_chg_230',
#  'mean_chg_231',
#  'mean_chg_232',
#  'mean_chg_233',
#  'mean_chg_234',
#  'mean_chg_235',
#  'mean_chg_236',
#  'mean_chg_237',
#  'mean_chg_238',
#  'mean_chg_239',
#  'mean_chg_240',
#  'mean_chg_241',
#  'mean_chg_242',
#  'mean_chg_243',
#  'mean_chg_244',
#  'mean_chg_245',
#  'mean_chg_246',
#  'mean_chg_247',
#  'mean_chg_248',
#  'mean_chg_249',
#  'mean_chg_250',
#  'mean_chg_251',
#  'mean_chg_252',
#  'mean_chg_253',
#  'mean_chg_254',
#  'mean_chg_255',
#  'mean_chg_256',
#  'mean_chg_257',
#  'mean_chg_258',
#  'mean_chg_259',
#  'mean_chg_260',
#  'mean_chg_261',
#  'mean_chg_262',
#  'mean_chg_263',
#  'mean_chg_264',
#  'mean_chg_265',
#  'mean_chg_266',
#  'mean_chg_267',
#  'mean_chg_268',
#  'mean_chg_269',
#  'mean_chg_270',
#  'mean_chg_271',
#  'mean_chg_272',
#  'mean_chg_273',
#  'mean_chg_274',
#  'mean_chg_275',
#  'mean_chg_276',
#  'mean_chg_277',
#  'mean_chg_278',
#  'mean_chg_279',
#  'mean_chg_280',
#  'mean_chg_281',
#  'mean_chg_282',
#  'mean_chg_283',
#  'mean_chg_284',
#  'mean_chg_285',
#  'mean_chg_286',
#  'mean_chg_287',
#  'mean_chg_288',
#  'mean_chg_289',
#  'mean_chg_290',
#  'mean_chg_291',
#  'mean_chg_292',
#  'mean_chg_293',
#  'mean_chg_294',
#  'mean_chg_295',
#  'mean_chg_296',
#  'mean_chg_297',
#  'mean_chg_298',
#  'mean_chg_299',
#  'mean_chg_300',
#  'mean_chg_301',
#  'mean_chg_302',
#  'mean_chg_303',
#  'mean_chg_304',
#  'mean_chg_305',
#  'mean_chg_306',
#  'mean_chg_307',
#  'mean_chg_308',
#  'mean_chg_309',
#  'mean_chg_310',
#  'mean_chg_311',
#  'mean_chg_312',
#  'mean_chg_313',
#  'mean_chg_314',
#  'mean_chg_315',
#  'mean_chg_316',
#  'mean_chg_317',
#  'mean_chg_318',
#  'mean_chg_319',
#  'mean_chg_320',
#  'mean_chg_321',
#  'mean_chg_322',
#  'mean_chg_323',
#  'mean_chg_324',
#  'mean_chg_325',
#  'mean_chg_326',
#  'mean_chg_327',
#  'mean_chg_328',
#  'mean_chg_329',
#  'mean_chg_330',
#  'mean_chg_331',
#  'mean_chg_332',
#  'mean_chg_333',
#  'mean_chg_334',
#  'mean_chg_335',
#  'mean_chg_336',
#  'mean_chg_337',
#  'mean_chg_338',
#  'mean_chg_339',
#  'mean_chg_340',
#  'mean_chg_341',
#  'mean_chg_342',
#  'mean_chg_343',
#  'mean_chg_344',
#  'mean_chg_345',
#  'mean_chg_346',
#  'mean_chg_347',
#  'mean_chg_348',
#  'mean_chg_349',
#  'mean_chg_350',
#  'mean_chg_351',
#  'mean_chg_352',
#  'mean_chg_353',
#  'mean_chg_354',
#  'mean_chg_355',
#  'mean_chg_356',
#  'mean_chg_357',
#  'mean_chg_358',
#  'mean_chg_359',
#  'mean_chg_360',
#  'mean_chg_361',
#  'mean_chg_362',
#  'mean_chg_363',
#  'mean_chg_364',
#  'mean_chg_365',
#  'mean_chg_366',
#  'mean_chg_367',
#  'mean_chg_368',
#  'mean_chg_369',
#  'mean_chg_370',
#  'mean_chg_371',
#  'mean_chg_372',
#  'mean_chg_373',
#  'mean_chg_374',
#  'mean_chg_375',
#  'mean_chg_376',
#  'mean_chg_377',
#  'rdf_0',
#  'rdf_1',
#  'rdf_2',
#  'rdf_3',
#  'rdf_4',
#  'rdf_5',
#  'rdf_6',
#  'rdf_7',
#  'rdf_8',
#  'rdf_9',
#  'rdf_10',
#  'rdf_11',
#  'rdf_12',
#  'rdf_13',
#  'rdf_14',
#  'rdf_15',
#  'rdf_16',
#  'rdf_17',
#  'rdf_18',
#  'rdf_19',
#  'rdf_20',
#  'rdf_21',
#  'rdf_22',
#  'rdf_23',
#  'rdf_24',
#  'rdf_25',
#  'rdf_26',
#  'rdf_27',
#  'rdf_28',
#  'rdf_29',
#  'rdf_30',
#  'rdf_31',
#  'rdf_32',
#  'rdf_33',
#  'rdf_34',
#  'rdf_35',
#  'rdf_36',
#  'rdf_37',
#  'rdf_38',
#  'rdf_39',
#  'rdf_40',
#  'rdf_41',
#  'rdf_42',
#  'rdf_43',
#  'rdf_44',
#  'rdf_45',
#  'rdf_46',
#  'rdf_47',
#  'rdf_48',
#  'rdf_49',
#  'rdf_50',
#  'rdf_51',
#  'rdf_52',
#  'rdf_53',
#  'rdf_54',
#  'rdf_55',
#  'rdf_56',
#  'rdf_57',
#  'rdf_58',
#  'rdf_59',
#  'rdf_60',
#  'rdf_61',
#  'rdf_62',
#  'rdf_63',
#  'rdf_64',
#  'rdf_65',
#  'rdf_66',
#  'rdf_67',
#  'rdf_68',
#  'rdf_69',
#  'rdf_70',
#  'rdf_71',
#  'rdf_72',
#  'rdf_73',
#  'rdf_74',
#  'rdf_75',
#  'rdf_76',
#  'rdf_77',
#  'rdf_78',
#  'rdf_79',
#  'rdf_80',
#  'rdf_81',
#  'rdf_82',
#  'rdf_83',
#  'rdf_84',
#  'rdf_85',
#  'rdf_86',
#  'rdf_87',
#  'rdf_88',
#  'rdf_89',
#  'rdf_90',
#  'rdf_91',
#  'rdf_92',
#  'rdf_93',
#  'rdf_94',
#  'rdf_95',
#  'rdf_96',
#  'rdf_97',
#  'rdf_98',
#  'rdf_99',
#  'adfa_0',
#  'adfa_1',
#  'adfa_2',
#  'adfa_3',
#  'adfa_4',
#  'adfa_5',
#  'adfa_6',
#  'adfa_7',
#  'adfa_8',
#  'adfa_9',
#  'adfa_10',
#  'adfa_11',
#  'adfa_12',
#  'adfa_13',
#  'adfa_14',
#  'adfa_15',
#  'adfa_16',
#  'adfa_17',
#  'adfa_18',
#  'adfa_19',
#  'adfa_20',
#  'adfa_21',
#  'adfa_22',
#  'adfa_23',
#  'adfa_24',
#  'adfa_25',
#  'adfa_26',
#  'adfa_27',
#  'adfa_28',
#  'adfa_29',
#  'adfa_30',
#  'adfa_31',
#  'adfa_32',
#  'adfa_33',
#  'adfa_34',
#  'adfa_35',
#  'adfa_36',
#  'adfa_37',
#  'adfa_38',
#  'adfa_39',
#  'adfa_40',
#  'adfa_41',
#  'adfa_42',
#  'adfa_43',
#  'adfa_44',
#  'adfa_45',
#  'adfa_46',
#  'adfa_47',
#  'adfa_48',
#  'adfa_49',
#  'adfa_50',
#  'adfa_51',
#  'adfa_52',
#  'adfa_53',
#  'adfa_54',
#  'adfa_55',
#  'adfa_56',
#  'adfa_57',
#  'adfa_58',
#  'adfa_59',
#  'adfa_60',
#  'adfa_61',
#  'adfa_62',
#  'adfa_63',
#  'adfa_64',
#  'adfa_65',
#  'adfa_66',
#  'adfa_67',
#  'adfa_68',
#  'adfa_69',
#  'adfa_70',
#  'adfa_71',
#  'adfa_72',
#  'adfa_73',
#  'adfa_74',
#  'adfa_75',
#  'adfa_76',
#  'adfa_77',
#  'adfa_78',
#  'adfa_79',
#  ...]

# %%
# Documentation says this should exist...
jarvis.ai.descriptors.elemental.get_element_fraction_desc(formula='SiO2', max_nelements=103)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 # Documentation says this should exist...
# ----> 2 jarvis.ai.descriptors.elemental.get_element_fraction_desc(formula='SiO2', max_nelements=103)
#
# AttributeError: module 'jarvis.ai.descriptors' has no attribute 'elemental'

# %% [markdown]
# ## Using with CBFV
#
# ***Authors: Steven Kauwe, Andrew Falkowski, Anthony Wang***
#
# Following tutorial here:
#
#     https://pypi.org/project/CBFV/
#
# Repo here:
#
#     https://github.com/Kaaiian/CBFV/blob/master/README.md

# %%
formula_unitcell
# Out:
#      Formula  Unit cell volume, A^3
# 0       CeGa                210.590
# 1       CeGa                212.790
# 2       CeGa                212.790
# 3       CeGa                215.020
# 4       CeGa                215.030
# ...      ...                    ...
# 1447    NiPt                 26.500
# 1448    NiPt                 26.473
# 1449    SnYb                 54.147
# 1450    SnYb                 54.800
# 1451    SnYb                 54.000
#
# [1452 rows x 2 columns]

# %%
import pandas as pd

data = {
    'formula': formula_unitcell['Formula'].tolist(),
    'target': formula_unitcell['Unit cell volume, A^3'].tolist()
}

df = pd.DataFrame(data)
print(df)
# Out:
#      formula   target
# 0       CeGa  210.590
# 1       CeGa  212.790
# 2       CeGa  212.790
# 3       CeGa  215.020
# 4       CeGa  215.030
# ...      ...      ...
# 1447    NiPt   26.500
# 1448    NiPt   26.473
# 1449    SnYb   54.147
# 1450    SnYb   54.800
# 1451    SnYb   54.000
#
# [1452 rows x 2 columns]

# %%
from CBFV import composition
X, y, formulae, skipped = composition.generate_features(formula_unitcell,
                                                        elem_prop='JARVIS',
                                                        drop_duplicates=False,
                                                        extend_features=True,
                                                        sum_feat=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 from CBFV import composition
# ----> 2 X, y, formulae, skipped = composition.generate_features(formula_unitcell,
#       3                                                         elem_prop='JARVIS',
#       4                                                         drop_duplicates=False,
#       5                                                         extend_features=True,
#       6                                                         sum_feat=True)
#
# File ~/anaconda3/envs/MLProj/lib/python3.8/site-packages/CBFV/composition.py:276, in generate_features(df, elem_prop, drop_duplicates, extend_features, sum_feat, mini)
#     274 if extend_features:
#     275     features = df.columns.values.tolist()
# --> 276     features.remove('target')
#     277     extra_features = df[features]
#     279 for index in tqdm.tqdm(df.index.values, desc='Processing Input Data'):
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ## Discrepancy with # of features...
#
# 3066 with CBFV vs. 1557 + unknown from element & coloumb matrix features
#
# see documentation:
#
#     https://jarvis-tools.readthedocs.io/en/master/autoapi/jarvis/ai/descriptors/index.html

# %%
X #features
# Out:
#    sum_C-0  sum_C-1  sum_C-10  sum_C-11  sum_C-12  sum_C-13  sum_C-14  \
# 0    749.1    361.7       0.0       0.0     333.0     333.0     797.5
# 1    175.8    124.2       0.0       0.0     124.2     124.2     175.8
# 2    188.5    176.2       0.0       0.0     106.9     106.9     135.4
#
#    sum_C-15  sum_C-16  sum_C-17  ...  mode_voro_coord_subs_atom_mass  \
# 0       0.0       0.0       0.0  ...                         -86.000
# 1       0.0       0.0       0.0  ...                        -150.500
# 2       0.0       0.0       0.0  ...                        -102.411
#
#    mode_voro_coord_subs_atom_rad  mode_voro_coord_subs_bp  \
# 0                           8.65                  -4526.0
# 1                          10.25                  -3188.0
# 2                           8.45                  -1030.0
#
#    mode_voro_coord_subs_elec_aff  mode_voro_coord_subs_first_ion_en  \
# 0                          9.494                            3.25381
# 1                         10.816                            4.27362
# 2                         10.000                            1.00618
#
#    mode_voro_coord_subs_hfus  mode_voro_coord_subs_mol_vol  \
# 0                     9.7850                          1.68
# 1                    11.8640                         -7.01
# 2                     9.9379                         -3.00
#
#    mode_voro_coord_subs_mp  mode_voro_coord_subs_polzbl  \
# 0                 -2418.00                        -2.40
# 1                 -1668.00                       -12.50
# 2                  -584.22                         2.68
#
#    mode_voro_coord_subs_therm_cond
# 0                            -39.0
# 1                           -388.0
# 2                            -87.0
#
# [3 rows x 3066 columns]

# %%
y #target
# Out:
# 0    248.5390
# 1     66.8444
# 2     91.5034
# Name: target, dtype: float64

# %%
formulae #Formulas
# Out:
# 0     Tc1V1
# 1    Cu1Dy1
# 2     Cd3N2
# Name: formula, dtype: object
